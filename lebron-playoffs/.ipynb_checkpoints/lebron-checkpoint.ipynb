# %%
from nba_py import player
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import requests 

from matplotlib.patches import Circle
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)
from matplotlib.cbook import get_sample_data


# %matplotlib inline

# %%
bpm = pd.read_csv("lebron - BPM per playoffs.csv").iloc[:,1:8]
vorp = pd.read_csv("lebron - VORP per playoffs.csv").iloc[:,1:8]
# print(bpm.columns.values[1:-1])
df = bpm.merge(vorp, on=['Player', 'Season', 'Age', 'Tm', 'Lg', 'G'])
df = df[(df.BPM != 'BPM') & (df.VORP != 'VORP')]
df.VORP = df.VORP.astype(float)
df.BPM = df.BPM.astype(float)
# df.dtypes
df.reset_index(inplace=True)

# %%
players = df.Player.unique()
playerList = [x.lower().split(" ") for x in players]
# print(player.get_player('lebron', 'james', only_current=0))
ids = [player.get_player(p[0],p[1]) for p in playerList]
# Out:
# [1844    2544
#  Name: PERSON_ID, dtype: int64, 2004    893
#  Name: PERSON_ID, dtype: int64, 4041    201566
#  Name: PERSON_ID, dtype: int64, 1011    1495
#  Name: PERSON_ID, dtype: int64, 817    201939
#  Name: PERSON_ID, dtype: int64, 304    1449
#  Name: PERSON_ID, dtype: int64, 1924    77142
#  Name: PERSON_ID, dtype: int64, 2866    165
#  Name: PERSON_ID, dtype: int64, 3028    937
#  Name: PERSON_ID, dtype: int64, 989    17
#  Name: PERSON_ID, dtype: int64, 3924    2548
#  Name: PERSON_ID, dtype: int64, 1338    1938
#  Name: PERSON_ID, dtype: int64, 3748    78318
#  Name: PERSON_ID, dtype: int64, 1415    203110
#  Name: PERSON_ID, dtype: int64, 2821    1717
#  Name: PERSON_ID, dtype: int64, 1728    204
#  Name: PERSON_ID, dtype: int64, 1102    76681
#  Name: PERSON_ID, dtype: int64, 498    977
#  Name: PERSON_ID, dtype: int64, 1531    201935
#  Name: PERSON_ID, dtype: int64, 3274    200765
#  Name: PERSON_ID, dtype: int64, 1018    201142
#  Name: PERSON_ID, dtype: int64, 3950    1112
#  Name: PERSON_ID, dtype: int64, 2844    406
#  Name: PERSON_ID, dtype: int64, 1740    2730
#  Name: PERSON_ID, dtype: int64, 2364    252
#  Name: PERSON_ID, dtype: int64, 55    951
#  Name: PERSON_ID, dtype: int64, 2067    467
#  Name: PERSON_ID, dtype: int64, 188    787
#  Name: PERSON_ID, dtype: int64, 3642    304
#  Name: PERSON_ID, dtype: int64, 1392    270
#  Name: PERSON_ID, dtype: int64, 2246    202695
#  Name: PERSON_ID, dtype: int64, 2    76003
#  Name: PERSON_ID, dtype: int64, 1296    2200
#  Name: PERSON_ID, dtype: int64, 298    1497
#  Name: PERSON_ID, dtype: int64, 1283    708
#  Name: PERSON_ID, dtype: int64]

# %%
for i in ids:
    i = i.tolist()[0]
    url = 'https://ak-static.cms.nba.com/wp-content/uploads/headshots/nba/latest/260x190/{}.png'.format(i)
    r = requests.get(url)
    
    open('{}.png'.format(i), 'wb').write(r.content)

# %%
# plt.scatter(df.BPM, df.VORP)
groups = df.groupby('Player')

# Plot
fig, ax = plt.subplots()
# ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.BPM, group.VORP, marker='o', linestyle='', ms=12, label=name)
    
    arr_img = plt.imread("2544.png", format='png')

    imagebox = OffsetImage(arr_img, zoom=0.3)
    # imagebox.image.axes = ax

    ab = AnnotationBbox(imagebox, (14,3),
                        xycoords='data',
                        frameon=False,
                        boxcoords="offset points",

                        )

    ax.add_artist(ab)
    
# ax.legend()
ax.set_xlabel('BPM')
ax.set_ylabel('VORP')
# Out:
# Text(0,0.5,'VORP')

# %%
fig, ax = plt.subplots()
# ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
print(df.BPM)
for n in range(df.shape[0]):
   
    ax.plot(group.BPM, group.VORP, marker='o', linestyle='', ms=12, label=name)
    
    arr_img = plt.imread("2544.png", format='png')

    imagebox = OffsetImage(arr_img, zoom=0.2)
    # imagebox.image.axes = ax

    ab = AnnotationBbox(imagebox, (df.BPM[n],df.VORP[n]),
                        xycoords='data',
                        frameon=False,
                        boxcoords="offset points",

                        )

    ax.add_artist(ab)
    
# ax.legend()
ax.set_xlabel('BPM')
ax.set_ylabel('VORP')
# Out:
# 0     14.7
# 1     14.3
# 2     13.8
# 3     13.1
# 4     12.8
# 5     11.7
# 6     11.6
# 7     11.5
# 8     11.0
# 9     11.0
# 10    10.9
# 11    10.8
# 12    10.4
# 13    10.3
# 14    10.2
# 15    10.2
# 16     9.7
# 17     9.6
# 18     9.6
# 19     9.3
# 20     9.1
# 21     9.1
# 22     8.9
# 23     8.9
# 24     8.7
# 25     8.7
# 26     8.7
# 27     8.7
# 28     8.6
# 29     8.5
#       ...
# 48     7.3
# 49     7.3
# 50     7.3
# 51     7.2
# 52     7.2
# 53     7.2
# 54     7.2
# 55     7.1
# 56     7.1
# 57     7.1
# 58     7.0
# 59     7.0
# 60     6.9
# 61     6.9
# 62     6.8
# 63     6.8
# 64     6.8
# 65     6.7
# 66     6.7
# 67     6.6
# 68     6.6
# 69     6.6
# 70     6.6
# 71     6.5
# 72     6.5
# 73     6.4
# 74     6.4
# 75     6.4
# 76     6.3
# 77     6.2
# Name: BPM, Length: 78, dtype: float64
# Text(0,0.5,'VORP')

# %%
fig, ax = plt.subplots()

# Define a 2nd position to annotate (don't display with a marker this time)
xy = [0.3, 0.55]

# Annotate the 2nd position with a circle patch
da = DrawingArea(20, 20, 0, 0)
p = Circle((10, 10), 10)
da.add_artist(p)



# Annotate the 2nd position with an image (a generated array of pixels)
arr = np.arange(100).reshape((10, 10))
im = OffsetImage(arr, zoom=1)
im.image.axes = ax

ab = AnnotationBbox(im, xy,
#                     xybox=(50., 50.),
                    xycoords='data',
                    boxcoords="offset points",
                    pad=0.3)
#                     arrowprops=dict(arrowstyle="->"))

ax.add_artist(ab)

arr_img = plt.imread("2544.png", format='png')

imagebox = OffsetImage(arr_img, zoom=0.3)
# imagebox.image.axes = ax

ab = AnnotationBbox(imagebox, xy,
                    xybox=(120., -80.),
                    xycoords='data',
                    frameon=False,
                    boxcoords="offset points",
            
                    )

ax.add_artist(ab)

ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
# Out:
# (0, 1)
