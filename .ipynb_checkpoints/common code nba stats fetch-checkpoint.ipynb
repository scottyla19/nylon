# %%
from nba_py import player, game
import pandas as pd
import json
import time
import random
import requests

# %%
response = game.PlayByPlay('0021600001')
response.json
# Out:
# {'parameters': {'EndPeriod': 0, 'GameID': '0021600001', 'StartPeriod': 0},
#  'resource': 'playbyplay',
#  'resultSets': [{'headers': ['GAME_ID',
#     'EVENTNUM',
#     'EVENTMSGTYPE',
#     'EVENTMSGACTIONTYPE',
#     'PERIOD',
#     'WCTIMESTRING',
#     'PCTIMESTRING',
#     'HOMEDESCRIPTION',
#     'NEUTRALDESCRIPTION',
#     'VISITORDESCRIPTION',
#     'SCORE',
#     'SCOREMARGIN'],
#    'name': 'PlayByPlay',
#    'rowSet': [['0021600001',
#      0,
#      12,
#      0,
#      1,
#      '7:37 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      1,
#      10,
#      0,
#      1,
#      '7:37 PM',
#      '12:00',
#      'Jump Ball Thompson vs. Noah: Tip to Rose',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      2,
#      1,
#      42,
#      1,
#      '7:37 PM',
#      '11:40',
#      None,
#      None,
#      "Rose 1' Driving Layup (2 PTS) (Noah 1 AST)",
#      '2 - 0',
#      '-2'],
#     ['0021600001',
#      3,
#      2,
#      3,
#      1,
#      '7:37 PM',
#      '11:26',
#      "MISS Love 4' Hook Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      4,
#      4,
#      0,
#      1,
#      '7:37 PM',
#      '11:23',
#      None,
#      None,
#      'Noah REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      5,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '11:16',
#      None,
#      None,
#      "MISS Anthony 20' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      6,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '11:15',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      7,
#      1,
#      97,
#      1,
#      '7:38 PM',
#      '11:15',
#      None,
#      None,
#      "Porzingis 2' Tip Layup Shot (2 PTS)",
#      '4 - 0',
#      '-4'],
#     ['0021600001',
#      8,
#      1,
#      1,
#      1,
#      '7:38 PM',
#      '10:59',
#      "James 11' Jump Shot (2 PTS) (Irving 1 AST)",
#      None,
#      None,
#      '4 - 2',
#      '-2'],
#     ['0021600001',
#      9,
#      5,
#      40,
#      1,
#      '7:38 PM',
#      '10:58',
#      None,
#      None,
#      'Rose Out of Bounds Lost Ball Turnover (P1.T1)',
#      None,
#      None],
#     ['0021600001',
#      10,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:46',
#      "MISS Irving 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      11,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '10:45',
#      None,
#      None,
#      'Lee REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      12,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:34',
#      None,
#      None,
#      "MISS Lee 18' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      13,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '10:33',
#      'Love REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      14,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:21',
#      "MISS Love 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      15,
#      4,
#      0,
#      1,
#      '7:39 PM',
#      '10:21',
#      None,
#      None,
#      'Noah REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      16,
#      6,
#      4,
#      1,
#      '7:39 PM',
#      '10:11',
#      None,
#      None,
#      'Noah OFF.Foul (P1) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      17,
#      5,
#      5,
#      1,
#      '7:39 PM',
#      '10:11',
#      None,
#      None,
#      'Noah Foul Turnover (P1.T2)',
#      None,
#      None],
#     ['0021600001',
#      18,
#      1,
#      98,
#      1,
#      '7:39 PM',
#      '9:59',
#      'Smith  Cutting Layup Shot (2 PTS) (James 1 AST)',
#      None,
#      None,
#      '4 - 4',
#      'TIE'],
#     ['0021600001',
#      19,
#      2,
#      1,
#      1,
#      '7:39 PM',
#      '9:47',
#      None,
#      None,
#      "MISS Porzingis 16' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      20,
#      4,
#      0,
#      1,
#      '7:39 PM',
#      '9:47',
#      None,
#      None,
#      'Noah REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      21,
#      6,
#      2,
#      1,
#      '7:40 PM',
#      '9:44',
#      'James S.FOUL (P1.T1) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      22,
#      3,
#      11,
#      1,
#      '7:40 PM',
#      '9:44',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (3 PTS)',
#      '5 - 4',
#      '-1'],
#     ['0021600001',
#      24,
#      3,
#      12,
#      1,
#      '7:40 PM',
#      '9:44',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      26,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:44',
#      'Thompson REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      27,
#      2,
#      1,
#      1,
#      '7:40 PM',
#      '9:33',
#      "MISS Love 20' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      28,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:32',
#      'Irving REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      29,
#      2,
#      1,
#      1,
#      '7:40 PM',
#      '9:27',
#      "MISS James 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      30,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:27',
#      None,
#      None,
#      'Noah REBOUND (Off:1 Def:3)',
#      None,
#      None],
#     ['0021600001',
#      31,
#      2,
#      78,
#      1,
#      '7:41 PM',
#      '9:18',
#      None,
#      None,
#      "MISS Rose 12' Floating Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      32,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:16',
#      None,
#      None,
#      'Rose REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      33,
#      2,
#      1,
#      1,
#      '7:41 PM',
#      '9:08',
#      None,
#      None,
#      "MISS Lee 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      34,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:07',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      35,
#      2,
#      97,
#      1,
#      '7:41 PM',
#      '9:07',
#      None,
#      None,
#      "MISS Anthony 1' Tip Layup Shot",
#      None,
#      None],
#     ['0021600001',
#      36,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:06',
#      'Love REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      37,
#      2,
#      47,
#      1,
#      '7:41 PM',
#      '8:58',
#      "MISS Thompson 9' Turnaround Jump Shot",
#      None,
#      'Porzingis BLOCK (1 BLK)',
#      None,
#      None],
#     ['0021600001',
#      38,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '8:56',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      39,
#      1,
#      1,
#      1,
#      '7:41 PM',
#      '8:47',
#      None,
#      None,
#      "Anthony 16' Jump Shot (2 PTS)",
#      '7 - 4',
#      '-3'],
#     ['0021600001',
#      40,
#      2,
#      1,
#      1,
#      '7:42 PM',
#      '8:16',
#      "MISS James 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      41,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:15',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      42,
#      2,
#      5,
#      1,
#      '7:42 PM',
#      '8:09',
#      None,
#      None,
#      "MISS Rose 1' Layup",
#      None,
#      None],
#     ['0021600001',
#      43,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:06',
#      'James REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      44,
#      2,
#      5,
#      1,
#      '7:42 PM',
#      '8:01',
#      'MISS Irving  Layup',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      45,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:01',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      46,
#      1,
#      1,
#      1,
#      '7:42 PM',
#      '7:56',
#      "Smith 25' 3PT Jump Shot (5 PTS) (James 2 AST)",
#      None,
#      None,
#      '7 - 7',
#      'TIE'],
#     ['0021600001',
#      47,
#      5,
#      1,
#      1,
#      '7:43 PM',
#      '7:42',
#      'Love STEAL (1 STL)',
#      None,
#      'Anthony Bad Pass Turnover (P1.T3)',
#      None,
#      None],
#     ['0021600001',
#      48,
#      2,
#      1,
#      1,
#      '7:43 PM',
#      '7:33',
#      "MISS Smith 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      49,
#      4,
#      0,
#      1,
#      '7:43 PM',
#      '7:32',
#      None,
#      None,
#      'Rose REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      51,
#      9,
#      1,
#      1,
#      '7:43 PM',
#      '7:28',
#      'CAVALIERS Timeout: Regular (Full 1 Short 0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      56,
#      1,
#      1,
#      1,
#      '7:46 PM',
#      '7:12',
#      None,
#      None,
#      'Anthony  3PT Jump Shot (5 PTS) (Rose 1 AST)',
#      '10 - 7',
#      '-3'],
#     ['0021600001',
#      57,
#      6,
#      1,
#      1,
#      '7:46 PM',
#      '7:03',
#      None,
#      None,
#      'Anthony P.FOUL (P1.T1) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      58,
#      2,
#      1,
#      1,
#      '7:47 PM',
#      '6:52',
#      "MISS Smith 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      59,
#      4,
#      0,
#      1,
#      '7:47 PM',
#      '6:52',
#      'James REBOUND (Off:1 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      60,
#      1,
#      42,
#      1,
#      '7:47 PM',
#      '6:48',
#      "Love 2' Driving Layup (2 PTS) (James 3 AST)",
#      None,
#      None,
#      '10 - 9',
#      '-1'],
#     ['0021600001',
#      61,
#      6,
#      2,
#      1,
#      '7:47 PM',
#      '6:48',
#      None,
#      None,
#      'Porzingis S.FOUL (P1.T2) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      62,
#      3,
#      10,
#      1,
#      '7:47 PM',
#      '6:48',
#      'Love Free Throw 1 of 1 (3 PTS)',
#      None,
#      None,
#      '10 - 10',
#      'TIE'],
#     ['0021600001',
#      65,
#      2,
#      5,
#      1,
#      '7:48 PM',
#      '6:24',
#      None,
#      None,
#      'MISS Noah  Layup',
#      None,
#      None],
#     ['0021600001',
#      66,
#      4,
#      0,
#      1,
#      '7:48 PM',
#      '6:24',
#      'Smith REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      67,
#      1,
#      1,
#      1,
#      '7:48 PM',
#      '6:13',
#      "Irving 15' Jump Shot (2 PTS) (James 4 AST)",
#      None,
#      None,
#      '10 - 12',
#      '2'],
#     ['0021600001',
#      68,
#      5,
#      2,
#      1,
#      '7:48 PM',
#      '6:02',
#      'Irving STEAL (1 STL)',
#      None,
#      'Rose Lost Ball Turnover (P2.T4)',
#      None,
#      None],
#     ['0021600001',
#      69,
#      1,
#      41,
#      1,
#      '7:48 PM',
#      '5:56',
#      "James 1' Running Layup (4 PTS) (Love 1 AST)",
#      None,
#      None,
#      '10 - 14',
#      '4'],
#     ['0021600001',
#      70,
#      1,
#      1,
#      1,
#      '7:48 PM',
#      '5:38',
#      None,
#      None,
#      "Anthony 23' Jump Shot (7 PTS)",
#      '12 - 14',
#      '2'],
#     ['0021600001',
#      71,
#      2,
#      42,
#      1,
#      '7:49 PM',
#      '5:25',
#      "MISS Irving 2' Driving Layup",
#      None,
#      'Rose BLOCK (1 BLK)',
#      None,
#      None],
#     ['0021600001',
#      72,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      74,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      'SUB: Jefferson FOR Love',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      75,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      None,
#      None,
#      'SUB: Jennings FOR Rose',
#      None,
#      None],
#     ['0021600001',
#      76,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      None,
#      None,
#      "SUB: O'Quinn FOR Noah",
#      None,
#      None],
#     ['0021600001',
#      77,
#      2,
#      47,
#      1,
#      '7:49 PM',
#      '5:16',
#      "MISS Smith 18' Turnaround Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      78,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:14',
#      None,
#      None,
#      'Jennings REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      79,
#      2,
#      42,
#      1,
#      '7:49 PM',
#      '5:05',
#      None,
#      None,
#      'MISS Porzingis  Driving Layup',
#      None,
#      None],
#     ['0021600001',
#      80,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:03',
#      'Thompson REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      81,
#      2,
#      5,
#      1,
#      '7:49 PM',
#      '5:00',
#      "MISS Irving 1' Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      82,
#      4,
#      0,
#      1,
#      '7:50 PM',
#      '5:00',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      83,
#      2,
#      1,
#      1,
#      '7:50 PM',
#      '4:34',
#      None,
#      None,
#      "MISS Jennings 20' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      84,
#      4,
#      0,
#      1,
#      '7:50 PM',
#      '4:34',
#      'James REBOUND (Off:1 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      85,
#      6,
#      1,
#      1,
#      '7:50 PM',
#      '4:34',
#      None,
#      None,
#      "O'Quinn P.FOUL (P1.T3) (B.Adams)",
#      None,
#      None],
#     ['0021600001',
#      87,
#      6,
#      17,
#      1,
#      '7:51 PM',
#      '4:25',
#      None,
#      None,
#      "Knicks T.Foul (Def. 3 Sec O'Quinn ) (B.Kennedy)",
#      None,
#      None],
#     ['0021600001',
#      88,
#      3,
#      16,
#      1,
#      '7:51 PM',
#      '4:25',
#      'Irving Free Throw Technical (3 PTS)',
#      None,
#      None,
#      '12 - 15',
#      '3'],
#     ['0021600001',
#      90,
#      8,
#      0,
#      1,
#      '7:51 PM',
#      '4:25',
#      None,
#      None,
#      'SUB: Thomas FOR Porzingis',
#      None,
#      None],
#     ['0021600001',
#      91,
#      8,
#      0,
#      1,
#      '7:51 PM',
#      '4:25',
#      'SUB: Shumpert FOR Smith',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      93,
#      1,
#      42,
#      1,
#      '7:51 PM',
#      '4:16',
#      "Irving 2' Driving Layup (5 PTS)",
#      None,
#      None,
#      '12 - 17',
#      '5'],
#     ['0021600001',
#      94,
#      1,
#      52,
#      1,
#      '7:52 PM',
#      '4:05',
#      None,
#      None,
#      "Anthony  Alley Oop Dunk (9 PTS) (O'Quinn 1 AST)",
#      '14 - 17',
#      '3'],
#     ['0021600001',
#      95,
#      2,
#      42,
#      1,
#      '7:52 PM',
#      '3:49',
#      "MISS Irving 2' Driving Layup",
#      None,
#      "O'Quinn BLOCK (1 BLK)",
#      None,
#      None],
#     ['0021600001',
#      96,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '3:46',
#      'Shumpert REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      97,
#      2,
#      1,
#      1,
#      '7:52 PM',
#      '3:41',
#      "MISS Jefferson 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      99,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '3:37',
#      'James REBOUND (Off:2 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      98,
#      1,
#      87,
#      1,
#      '7:52 PM',
#      '3:37',
#      'James  Putback Dunk (6 PTS)',
#      None,
#      None,
#      '14 - 19',
#      '5'],
#     ['0021600001',
#      100,
#      1,
#      1,
#      1,
#      '7:52 PM',
#      '3:17',
#      None,
#      None,
#      "Anthony 16' Jump Shot (11 PTS)",
#      '16 - 19',
#      '3'],
#     ['0021600001',
#      101,
#      2,
#      1,
#      1,
#      '7:53 PM',
#      '3:04',
#      "MISS Shumpert 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      102,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      103,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      'SUB: Dunleavy FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      105,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      'SUB: Love FOR Irving',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      106,
#      2,
#      1,
#      1,
#      '7:53 PM',
#      '2:50',
#      None,
#      None,
#      "MISS Thomas 23' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      107,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '2:50',
#      'Jefferson REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      108,
#      2,
#      40,
#      1,
#      '7:53 PM',
#      '2:43',
#      "MISS Love 2' Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      110,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '2:43',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      112,
#      9,
#      1,
#      1,
#      '7:54 PM',
#      '2:43',
#      None,
#      None,
#      'Knicks Timeout: Regular (Reg.1 Short 0)',
#      None,
#      None],
#     ['0021600001',
#      114,
#      18,
#      1,
#      1,
#      '7:54 PM',
#      '2:43',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      117,
#      2,
#      98,
#      1,
#      '7:56 PM',
#      '2:40',
#      "MISS Love 2' Cutting Layup Shot",
#      None,
#      "O'Quinn BLOCK (2 BLK)",
#      None,
#      None],
#     ['0021600001',
#      118,
#      4,
#      0,
#      1,
#      '7:56 PM',
#      '2:39',
#      None,
#      None,
#      'Lee REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      119,
#      6,
#      4,
#      1,
#      '7:57 PM',
#      '2:37',
#      None,
#      None,
#      "O'Quinn OFF.Foul (P2) (K.Lane)",
#      None,
#      None],
#     ['0021600001',
#      120,
#      5,
#      5,
#      1,
#      '7:57 PM',
#      '2:37',
#      None,
#      None,
#      "O'Quinn Foul Turnover (P1.T5)",
#      None,
#      None],
#     ['0021600001',
#      121,
#      1,
#      80,
#      1,
#      '7:57 PM',
#      '2:16',
#      "Love 14' Step Back Jump Shot (5 PTS) (Shumpert 1 AST)",
#      None,
#      None,
#      '16 - 21',
#      '5'],
#     ['0021600001',
#      122,
#      5,
#      2,
#      1,
#      '7:57 PM',
#      '2:00',
#      'Jefferson STEAL (1 STL)',
#      None,
#      'Anthony Lost Ball Turnover (P2.T6)',
#      None,
#      None],
#     ['0021600001',
#      123,
#      1,
#      50,
#      1,
#      '7:58 PM',
#      '1:55',
#      'Jefferson  Running Dunk (2 PTS)',
#      None,
#      None,
#      '16 - 23',
#      '7'],
#     ['0021600001',
#      124,
#      5,
#      45,
#      1,
#      '7:58 PM',
#      '1:40',
#      None,
#      None,
#      'Anthony Out of Bounds - Bad Pass Turnover Turnover (P3.T7)',
#      None,
#      None],
#     ['0021600001',
#      125,
#      8,
#      0,
#      1,
#      '7:58 PM',
#      '1:40',
#      None,
#      None,
#      'SUB: Holiday FOR Anthony',
#      None,
#      None],
#     ['0021600001',
#      126,
#      6,
#      2,
#      1,
#      '7:58 PM',
#      '1:28',
#      None,
#      None,
#      'Thomas S.FOUL (P1.T4) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      127,
#      3,
#      11,
#      1,
#      '7:59 PM',
#      '1:28',
#      'MISS Love Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      128,
#      4,
#      1,
#      1,
#      '7:59 PM',
#      '1:28',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      129,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '1:28',
#      None,
#      None,
#      'SUB: Hernangomez FOR Lee',
#      None,
#      None],
#     ['0021600001',
#      130,
#      3,
#      12,
#      1,
#      '7:59 PM',
#      '1:28',
#      'Love Free Throw 2 of 2 (6 PTS)',
#      None,
#      None,
#      '16 - 24',
#      '8'],
#     ['0021600001',
#      133,
#      2,
#      1,
#      1,
#      '7:59 PM',
#      '1:11',
#      None,
#      None,
#      "MISS O'Quinn 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      134,
#      4,
#      0,
#      1,
#      '7:59 PM',
#      '1:10',
#      'Love REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      135,
#      6,
#      4,
#      1,
#      '8:00 PM',
#      '1:06',
#      'Shumpert OFF.Foul (P1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      136,
#      5,
#      5,
#      1,
#      '8:00 PM',
#      '1:06',
#      'Shumpert Foul Turnover (P1.T1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      138,
#      6,
#      2,
#      1,
#      '8:00 PM',
#      '0:50',
#      'Thompson S.FOUL (P1.T2) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      139,
#      3,
#      11,
#      1,
#      '8:00 PM',
#      '0:50',
#      None,
#      None,
#      'Jennings Free Throw 1 of 2 (1 PTS)',
#      '17 - 24',
#      '7'],
#     ['0021600001',
#      141,
#      3,
#      12,
#      1,
#      '8:01 PM',
#      '0:50',
#      None,
#      None,
#      'Jennings Free Throw 2 of 2 (2 PTS)',
#      '18 - 24',
#      '6'],
#     ['0021600001',
#      144,
#      6,
#      1,
#      1,
#      '8:01 PM',
#      '0:40',
#      None,
#      None,
#      'Thomas P.FOUL (P2.PN) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      145,
#      3,
#      11,
#      1,
#      '8:01 PM',
#      '0:40',
#      'MISS Love Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      146,
#      4,
#      1,
#      1,
#      '8:01 PM',
#      '0:40',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      147,
#      8,
#      0,
#      1,
#      '8:02 PM',
#      '0:40',
#      'SUB: Frye FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      148,
#      3,
#      12,
#      1,
#      '8:02 PM',
#      '0:40',
#      'Love Free Throw 2 of 2 (7 PTS)',
#      None,
#      None,
#      '18 - 25',
#      '7'],
#     ['0021600001',
#      151,
#      2,
#      1,
#      1,
#      '8:02 PM',
#      '0:29',
#      None,
#      None,
#      "MISS Jennings 24' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      152,
#      4,
#      0,
#      1,
#      '8:02 PM',
#      '0:29',
#      None,
#      None,
#      'Hernangomez REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      153,
#      2,
#      1,
#      1,
#      '8:02 PM',
#      '0:09',
#      'Frye BLOCK (1 BLK)',
#      None,
#      "MISS Thomas 15' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      154,
#      4,
#      0,
#      1,
#      '8:02 PM',
#      '0:09',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      155,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      'SUB: Irving FOR Shumpert',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      156,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      'SUB: James FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      157,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      None,
#      None,
#      "SUB: Lee FOR O'Quinn",
#      None,
#      None],
#     ['0021600001',
#      159,
#      1,
#      1,
#      1,
#      '8:03 PM',
#      '0:03',
#      "Love 24' 3PT Jump Shot (10 PTS) (James 5 AST)",
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      161,
#      2,
#      1,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      "MISS Jennings 52' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      162,
#      4,
#      0,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      163,
#      13,
#      0,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      165,
#      12,
#      0,
#      2,
#      '8:07 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      166,
#      2,
#      1,
#      2,
#      '8:07 PM',
#      '11:46',
#      "MISS Frye 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      167,
#      4,
#      0,
#      2,
#      '8:07 PM',
#      '11:45',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      168,
#      2,
#      1,
#      2,
#      '8:07 PM',
#      '11:29',
#      None,
#      None,
#      "MISS Holiday 18' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      169,
#      4,
#      0,
#      2,
#      '8:07 PM',
#      '11:29',
#      'Irving REBOUND (Off:1 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      170,
#      2,
#      74,
#      2,
#      '8:07 PM',
#      '11:26',
#      "MISS Irving 3' Running Reverse Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      171,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '11:24',
#      'James REBOUND (Off:3 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      172,
#      2,
#      1,
#      2,
#      '8:08 PM',
#      '11:20',
#      'MISS Irving  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      173,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '11:19',
#      'Frye REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      174,
#      1,
#      7,
#      2,
#      '8:08 PM',
#      '10:55',
#      'James  Dunk (8 PTS) (Jefferson 1 AST)',
#      None,
#      None,
#      '18 - 30',
#      '12'],
#     ['0021600001',
#      175,
#      5,
#      1,
#      2,
#      '8:08 PM',
#      '10:47',
#      'Dunleavy STEAL (1 STL)',
#      None,
#      'Hernangomez Bad Pass Turnover (P1.T8)',
#      None,
#      None],
#     ['0021600001',
#      176,
#      2,
#      41,
#      2,
#      '8:08 PM',
#      '10:42',
#      "MISS James 3' Running Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      178,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '10:40',
#      'Frye REBOUND (Off:2 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      177,
#      2,
#      97,
#      2,
#      '8:08 PM',
#      '10:40',
#      "MISS Frye 1' Tip Layup Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      179,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '10:40',
#      None,
#      None,
#      'Thomas REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      180,
#      2,
#      1,
#      2,
#      '8:09 PM',
#      '10:23',
#      None,
#      None,
#      "MISS Thomas 22' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      181,
#      4,
#      0,
#      2,
#      '8:09 PM',
#      '10:23',
#      'Dunleavy REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      182,
#      2,
#      1,
#      2,
#      '8:09 PM',
#      '10:11',
#      "MISS Frye 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      183,
#      4,
#      0,
#      2,
#      '8:09 PM',
#      '10:11',
#      None,
#      None,
#      'Jennings REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      184,
#      1,
#      5,
#      2,
#      '8:09 PM',
#      '10:02',
#      None,
#      None,
#      "Hernangomez 1' Layup (2 PTS) (Jennings 1 AST)",
#      '20 - 30',
#      '10'],
#     ['0021600001',
#      185,
#      1,
#      7,
#      2,
#      '8:09 PM',
#      '9:46',
#      'Jefferson  Dunk (4 PTS) (James 6 AST)',
#      None,
#      None,
#      '20 - 32',
#      '12'],
#     ['0021600001',
#      189,
#      6,
#      2,
#      2,
#      '8:10 PM',
#      '9:36',
#      'Frye S.FOUL (P1.T1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      190,
#      3,
#      11,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'Jennings Free Throw 1 of 2 (3 PTS)',
#      '21 - 32',
#      '11'],
#     ['0021600001',
#      192,
#      8,
#      0,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'SUB: Porzingis FOR Hernangomez',
#      None,
#      None],
#     ['0021600001',
#      193,
#      3,
#      12,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'Jennings Free Throw 2 of 2 (4 PTS)',
#      '22 - 32',
#      '10'],
#     ['0021600001',
#      195,
#      6,
#      1,
#      2,
#      '8:11 PM',
#      '9:27',
#      None,
#      None,
#      'Porzingis P.FOUL (P2.T1) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      196,
#      8,
#      0,
#      2,
#      '8:11 PM',
#      '9:27',
#      None,
#      None,
#      'SUB: Rose FOR Jennings',
#      None,
#      None],
#     ['0021600001',
#      197,
#      2,
#      1,
#      2,
#      '8:11 PM',
#      '9:12',
#      "MISS Dunleavy 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      198,
#      4,
#      0,
#      2,
#      '8:11 PM',
#      '9:12',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      199,
#      1,
#      79,
#      2,
#      '8:11 PM',
#      '9:01',
#      None,
#      None,
#      "Rose 12' Pullup Jump Shot (4 PTS)",
#      '24 - 32',
#      '8'],
#     ['0021600001',
#      201,
#      2,
#      1,
#      2,
#      '8:11 PM',
#      '8:48',
#      "MISS Irving 15' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      202,
#      4,
#      0,
#      2,
#      '8:11 PM',
#      '8:48',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:0 Def:1)",
#      None,
#      None],
#     ['0021600001',
#      203,
#      5,
#      2,
#      2,
#      '8:12 PM',
#      '8:41',
#      'Jefferson STEAL (2 STL)',
#      None,
#      'Rose Lost Ball Turnover (P3.T9)',
#      None,
#      None],
#     ['0021600001',
#      204,
#      1,
#      50,
#      2,
#      '8:12 PM',
#      '8:36',
#      'James  Running Dunk (10 PTS) (Irving 2 AST)',
#      None,
#      None,
#      '24 - 34',
#      '10'],
#     ['0021600001',
#      205,
#      9,
#      1,
#      2,
#      '8:12 PM',
#      '8:36',
#      None,
#      None,
#      'Knicks Timeout: Regular (Reg.2 Short 0)',
#      None,
#      None],
#     ['0021600001',
#      207,
#      8,
#      0,
#      2,
#      '8:15 PM',
#      '8:36',
#      None,
#      None,
#      "SUB: Anthony FOR O'Quinn",
#      None,
#      None],
#     ['0021600001',
#      209,
#      5,
#      1,
#      2,
#      '8:15 PM',
#      '8:23',
#      'Frye STEAL (1 STL)',
#      None,
#      'Rose Bad Pass Turnover (P4.T10)',
#      None,
#      None],
#     ['0021600001',
#      210,
#      5,
#      40,
#      2,
#      '8:15 PM',
#      '8:12',
#      'Jefferson Out of Bounds Lost Ball Turnover (P1.T2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      211,
#      2,
#      1,
#      2,
#      '8:16 PM',
#      '7:58',
#      None,
#      None,
#      "MISS Porzingis 15' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      212,
#      4,
#      0,
#      2,
#      '8:16 PM',
#      '7:57',
#      'James REBOUND (Off:3 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      236,
#      5,
#      1,
#      2,
#      '8:16 PM',
#      '7:46',
#      'James Bad Pass Turnover (P1.T3)',
#      None,
#      'Porzingis STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      213,
#      6,
#      1,
#      2,
#      '8:16 PM',
#      '7:45',
#      'Irving P.FOUL (P1.T2) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      215,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Shumpert FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      216,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Smith FOR Dunleavy',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      217,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Thompson FOR Frye',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      218,
#      8,
#      0,
#      2,
#      '8:17 PM',
#      '7:45',
#      None,
#      None,
#      'SUB: Noah FOR Thomas',
#      None,
#      None],
#     ['0021600001',
#      219,
#      2,
#      1,
#      2,
#      '8:17 PM',
#      '7:36',
#      'Shumpert BLOCK (1 BLK)',
#      None,
#      "MISS Anthony 5' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      220,
#      4,
#      0,
#      2,
#      '8:17 PM',
#      '7:35',
#      'James REBOUND (Off:3 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      221,
#      1,
#      52,
#      2,
#      '8:17 PM',
#      '7:33',
#      'James  Alley Oop Dunk (12 PTS) (Irving 3 AST)',
#      None,
#      None,
#      '24 - 36',
#      '12'],
#     ['0021600001',
#      222,
#      6,
#      1,
#      2,
#      '8:17 PM',
#      '7:18',
#      'James P.FOUL (P2.T3) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      224,
#      1,
#      80,
#      2,
#      '8:18 PM',
#      '7:07',
#      None,
#      None,
#      "Rose 8' Step Back Jump Shot (6 PTS)",
#      '26 - 36',
#      '10'],
#     ['0021600001',
#      225,
#      1,
#      1,
#      2,
#      '8:18 PM',
#      '6:50',
#      "Smith 25' 3PT Jump Shot (8 PTS) (James 7 AST)",
#      None,
#      None,
#      '26 - 39',
#      '13'],
#     ['0021600001',
#      226,
#      1,
#      1,
#      2,
#      '8:18 PM',
#      '6:30',
#      None,
#      None,
#      "Anthony 15' Jump Shot (13 PTS)",
#      '28 - 39',
#      '11'],
#     ['0021600001',
#      227,
#      5,
#      1,
#      2,
#      '8:19 PM',
#      '6:16',
#      'Thompson Bad Pass Turnover (P1.T4)',
#      None,
#      'Noah STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      228,
#      1,
#      41,
#      2,
#      '8:19 PM',
#      '6:11',
#      None,
#      None,
#      'Rose  Running Layup (8 PTS)',
#      '30 - 39',
#      '9'],
#     ['0021600001',
#      229,
#      9,
#      1,
#      2,
#      '8:19 PM',
#      '6:11',
#      'CAVALIERS Timeout: Regular (Full 2 Short 0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      233,
#      6,
#      4,
#      2,
#      '8:22 PM',
#      '6:02',
#      'Thompson OFF.Foul (P2) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      234,
#      5,
#      5,
#      2,
#      '8:22 PM',
#      '6:02',
#      'Thompson Foul Turnover (P2.T5)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      237,
#      8,
#      0,
#      2,
#      '8:22 PM',
#      '6:02',
#      'SUB: Love FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      238,
#      1,
#      1,
#      2,
#      '8:23 PM',
#      '5:47',
#      None,
#      None,
#      "Porzingis 24' 3PT Jump Shot (6 PTS) (Holiday 1 AST)",
#      '33 - 39',
#      '6'],
#     ['0021600001',
#      239,
#      6,
#      1,
#      2,
#      '8:23 PM',
#      '5:33',
#      None,
#      None,
#      'Anthony P.FOUL (P2.T2) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      241,
#      2,
#      1,
#      2,
#      '8:24 PM',
#      '5:18',
#      "MISS Smith 17' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      242,
#      4,
#      0,
#      2,
#      '8:24 PM',
#      '5:18',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      243,
#      1,
#      1,
#      2,
#      '8:24 PM',
#      '5:11',
#      None,
#      None,
#      "Holiday 24' 3PT Jump Shot (3 PTS) (Anthony 1 AST)",
#      '36 - 39',
#      '3'],
#     ['0021600001',
#      244,
#      1,
#      42,
#      2,
#      '8:24 PM',
#      '4:55',
#      "Irving 1' Driving Layup (7 PTS)",
#      None,
#      None,
#      '36 - 41',
#      '5'],
#     ['0021600001',
#      245,
#      1,
#      1,
#      2,
#      '8:24 PM',
#      '4:40',
#      None,
#      None,
#      "Holiday 25' 3PT Jump Shot (6 PTS) (Anthony 2 AST)",
#      '39 - 41',
#      '2'],
#     ['0021600001',
#      246,
#      2,
#      1,
#      2,
#      '8:24 PM',
#      '4:29',
#      "MISS Love 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      247,
#      4,
#      0,
#      2,
#      '8:24 PM',
#      '4:28',
#      'Thompson REBOUND (Off:1 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      248,
#      2,
#      1,
#      2,
#      '8:25 PM',
#      '4:19',
#      "MISS Love 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      249,
#      4,
#      0,
#      2,
#      '8:25 PM',
#      '4:19',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      251,
#      1,
#      5,
#      2,
#      '8:25 PM',
#      '4:13',
#      None,
#      None,
#      "Rose 1' Layup (10 PTS)",
#      '41 - 41',
#      'TIE'],
#     ['0021600001',
#      253,
#      1,
#      1,
#      2,
#      '8:25 PM',
#      '3:59',
#      "Irving 24' 3PT Jump Shot (10 PTS)",
#      None,
#      None,
#      '41 - 44',
#      '3'],
#     ['0021600001',
#      254,
#      6,
#      1,
#      2,
#      '8:25 PM',
#      '3:46',
#      'Shumpert P.FOUL (P2.T4) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      255,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:41',
#      None,
#      None,
#      'MISS Rose  3PT Jump Shot',
#      None,
#      None],
#     ['0021600001',
#      256,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:40',
#      'Love REBOUND (Off:0 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      257,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:30',
#      "MISS Smith 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      258,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:30',
#      'Thompson REBOUND (Off:2 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      259,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:17',
#      "MISS Shumpert 19' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      260,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:17',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      261,
#      6,
#      1,
#      2,
#      '8:26 PM',
#      '3:17',
#      'Thompson P.FOUL (P3.PN) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      262,
#      3,
#      11,
#      2,
#      '8:26 PM',
#      '3:17',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (7 PTS)',
#      '42 - 44',
#      '2'],
#     ['0021600001',
#      264,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      'SUB: James FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      265,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      'SUB: Jefferson FOR Irving',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      266,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      None,
#      None,
#      'SUB: Lee FOR Noah',
#      None,
#      None],
#     ['0021600001',
#      267,
#      3,
#      12,
#      2,
#      '8:27 PM',
#      '3:17',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      269,
#      4,
#      0,
#      2,
#      '8:27 PM',
#      '3:16',
#      'Love REBOUND (Off:0 Def:5)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      271,
#      1,
#      49,
#      2,
#      '8:27 PM',
#      '3:09',
#      'Jefferson  Driving Dunk (6 PTS) (Shumpert 2 AST)',
#      None,
#      None,
#      '42 - 46',
#      '4'],
#     ['0021600001',
#      272,
#      2,
#      79,
#      2,
#      '8:28 PM',
#      '2:52',
#      None,
#      None,
#      "MISS Holiday 16' Pullup Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      273,
#      4,
#      0,
#      2,
#      '8:28 PM',
#      '2:50',
#      'Love REBOUND (Off:0 Def:6)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      274,
#      2,
#      1,
#      2,
#      '8:28 PM',
#      '2:44',
#      'MISS Smith  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      275,
#      4,
#      0,
#      2,
#      '8:28 PM',
#      '2:43',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      276,
#      6,
#      3,
#      2,
#      '8:28 PM',
#      '2:43',
#      None,
#      None,
#      'Anthony L.B.FOUL (P3.T3) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      277,
#      9,
#      4,
#      2,
#      '8:28 PM',
#      '2:43',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      279,
#      8,
#      0,
#      2,
#      '8:31 PM',
#      '2:43',
#      None,
#      None,
#      'SUB: Thomas FOR Anthony',
#      None,
#      None],
#     ['0021600001',
#      281,
#      5,
#      2,
#      2,
#      '8:31 PM',
#      '2:37',
#      'James Lost Ball Turnover (P2.T6)',
#      None,
#      'Thomas STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      282,
#      5,
#      2,
#      2,
#      '8:31 PM',
#      '2:28',
#      'Smith STEAL (1 STL)',
#      None,
#      'Lee Lost Ball Turnover (P1.T11)',
#      None,
#      None],
#     ['0021600001',
#      283,
#      5,
#      40,
#      2,
#      '8:31 PM',
#      '2:20',
#      'Jefferson Out of Bounds Lost Ball Turnover (P2.T7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      284,
#      2,
#      42,
#      2,
#      '8:32 PM',
#      '2:08',
#      None,
#      None,
#      "MISS Rose 1' Driving Layup",
#      None,
#      None],
#     ['0021600001',
#      285,
#      4,
#      0,
#      2,
#      '8:32 PM',
#      '2:07',
#      'Smith REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      287,
#      5,
#      1,
#      2,
#      '8:32 PM',
#      '1:54',
#      'Love Bad Pass Turnover (P1.T8)',
#      None,
#      'Holiday STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      288,
#      2,
#      1,
#      2,
#      '8:32 PM',
#      '1:47',
#      None,
#      None,
#      "MISS Lee 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      289,
#      4,
#      0,
#      2,
#      '8:32 PM',
#      '1:45',
#      None,
#      None,
#      'Rose REBOUND (Off:2 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      290,
#      1,
#      42,
#      2,
#      '8:32 PM',
#      '1:42',
#      None,
#      None,
#      'Rose  Driving Layup (12 PTS)',
#      '44 - 46',
#      '2'],
#     ['0021600001',
#      291,
#      2,
#      1,
#      2,
#      '8:33 PM',
#      '1:15',
#      "MISS James 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      292,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '1:15',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      293,
#      5,
#      11,
#      2,
#      '8:33 PM',
#      '1:15',
#      'CAVALIERS Turnover: Shot Clock (T#9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      294,
#      2,
#      1,
#      2,
#      '8:33 PM',
#      '1:05',
#      None,
#      None,
#      "MISS Porzingis 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      295,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '1:05',
#      'Love REBOUND (Off:0 Def:7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      296,
#      2,
#      78,
#      2,
#      '8:33 PM',
#      '0:52',
#      "MISS James 10' Floating Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      297,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '0:51',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:3)',
#      None,
#      None],
#     ['0021600001',
#      298,
#      6,
#      2,
#      2,
#      '8:33 PM',
#      '0:38',
#      'Love S.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      299,
#      3,
#      11,
#      2,
#      '8:34 PM',
#      '0:38',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (8 PTS)',
#      '45 - 46',
#      '1'],
#     ['0021600001',
#      301,
#      3,
#      12,
#      2,
#      '8:34 PM',
#      '0:38',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      303,
#      4,
#      0,
#      2,
#      '8:34 PM',
#      '0:36',
#      'Love REBOUND (Off:0 Def:8)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      304,
#      1,
#      79,
#      2,
#      '8:34 PM',
#      '0:27',
#      "Shumpert 14' Pullup Jump Shot (2 PTS)",
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      305,
#      9,
#      2,
#      2,
#      '8:35 PM',
#      '0:16',
#      None,
#      None,
#      'Knicks Timeout: Short (Reg.2 Short 1)',
#      None,
#      None],
#     ['0021600001',
#      307,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      None,
#      None,
#      'SUB: Anthony FOR Thomas',
#      None,
#      None],
#     ['0021600001',
#      308,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      'SUB: McRae FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      309,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      'SUB: Dunleavy FOR Shumpert',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      310,
#      2,
#      1,
#      2,
#      '8:36 PM',
#      '0:02',
#      None,
#      None,
#      "MISS Anthony 26' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      311,
#      4,
#      0,
#      2,
#      '8:36 PM',
#      '0:01',
#      None,
#      None,
#      'Porzingis REBOUND (Off:2 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      312,
#      2,
#      63,
#      2,
#      '8:36 PM',
#      '0:01',
#      None,
#      None,
#      "MISS Porzingis 10' Fadeaway Jumper",
#      None,
#      None],
#     ['0021600001',
#      313,
#      4,
#      0,
#      2,
#      '8:36 PM',
#      '0:00',
#      'Love REBOUND (Off:0 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      314,
#      13,
#      0,
#      2,
#      '8:36 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      316,
#      12,
#      0,
#      3,
#      '8:54 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      317,
#      2,
#      1,
#      3,
#      '8:54 PM',
#      '11:46',
#      "MISS Smith 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      318,
#      4,
#      0,
#      3,
#      '8:54 PM',
#      '11:46',
#      'Love REBOUND (Off:1 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      319,
#      6,
#      26,
#      3,
#      '8:55 PM',
#      '11:42',
#      'Love Offensive Charge Foul (P2.T1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      320,
#      5,
#      5,
#      3,
#      '8:55 PM',
#      '11:42',
#      'Love Foul Turnover (P2.T10)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      321,
#      2,
#      1,
#      3,
#      '8:55 PM',
#      '11:29',
#      None,
#      None,
#      "MISS Anthony 12' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      322,
#      4,
#      0,
#      3,
#      '8:55 PM',
#      '11:29',
#      'Thompson REBOUND (Off:2 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      323,
#      2,
#      1,
#      3,
#      '8:55 PM',
#      '11:07',
#      "MISS Irving 14' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      325,
#      4,
#      0,
#      3,
#      '8:55 PM',
#      '11:04',
#      'Love REBOUND (Off:2 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      324,
#      1,
#      97,
#      3,
#      '8:55 PM',
#      '11:04',
#      "Love 2' Tip Layup Shot (12 PTS)",
#      None,
#      None,
#      '45 - 50',
#      '5'],
#     ['0021600001',
#      326,
#      5,
#      1,
#      3,
#      '8:56 PM',
#      '10:51',
#      'Love STEAL (2 STL)',
#      None,
#      'Lee Bad Pass Turnover (P2.T12)',
#      None,
#      None],
#     ['0021600001',
#      327,
#      6,
#      29,
#      3,
#      '8:56 PM',
#      '10:47',
#      None,
#      None,
#      'Lee Shooting Block Foul (P1.T1) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      328,
#      3,
#      11,
#      3,
#      '8:56 PM',
#      '10:47',
#      'MISS James Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      329,
#      4,
#      1,
#      3,
#      '8:56 PM',
#      '10:47',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      330,
#      3,
#      12,
#      3,
#      '8:57 PM',
#      '10:47',
#      'James Free Throw 2 of 2 (13 PTS)',
#      None,
#      None,
#      '45 - 51',
#      '6'],
#     ['0021600001',
#      333,
#      2,
#      80,
#      3,
#      '8:57 PM',
#      '10:34',
#      None,
#      None,
#      "MISS Rose 17' Step Back Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      334,
#      4,
#      0,
#      3,
#      '8:57 PM',
#      '10:32',
#      None,
#      None,
#      'Lee REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      335,
#      5,
#      39,
#      3,
#      '8:57 PM',
#      '10:29',
#      None,
#      None,
#      'Anthony Step Out of Bounds Turnover (P4.T13)',
#      None,
#      None],
#     ['0021600001',
#      336,
#      2,
#      1,
#      3,
#      '8:57 PM',
#      '10:17',
#      "MISS Love 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      337,
#      4,
#      0,
#      3,
#      '8:58 PM',
#      '10:17',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      338,
#      2,
#      66,
#      3,
#      '8:58 PM',
#      '9:58',
#      None,
#      None,
#      "MISS Porzingis 13' Jump Bank Shot",
#      None,
#      None],
#     ['0021600001',
#      340,
#      4,
#      0,
#      3,
#      '8:58 PM',
#      '9:54',
#      None,
#      None,
#      'Porzingis REBOUND (Off:3 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      339,
#      1,
#      97,
#      3,
#      '8:58 PM',
#      '9:54',
#      None,
#      None,
#      'Porzingis  Tip Layup Shot (10 PTS)',
#      '47 - 51',
#      '4'],
#     ['0021600001',
#      341,
#      1,
#      1,
#      3,
#      '8:58 PM',
#      '9:35',
#      "Irving 28' 3PT Jump Shot (13 PTS) (Smith 1 AST)",
#      None,
#      None,
#      '47 - 54',
#      '7'],
#     ['0021600001',
#      342,
#      1,
#      1,
#      3,
#      '8:59 PM',
#      '9:22',
#      None,
#      None,
#      "Anthony 19' Jump Shot (15 PTS) (Noah 2 AST)",
#      '49 - 54',
#      '5'],
#     ['0021600001',
#      343,
#      1,
#      49,
#      3,
#      '8:59 PM',
#      '9:05',
# ...
#      None,
#      None],
#     ['0021600001',
#      481,
#      1,
#      1,
#      4,
#      '9:34 PM',
#      '8:34',
#      'Jefferson  3PT Jump Shot (9 PTS) (James 14 AST)',
#      None,
#      None,
#      '71 - 92',
#      '21'],
#     ['0021600001',
#      482,
#      1,
#      1,
#      4,
#      '9:35 PM',
#      '8:19',
#      None,
#      None,
#      "Rose 24' 3PT Jump Shot (17 PTS)",
#      '74 - 92',
#      '18'],
#     ['0021600001',
#      483,
#      2,
#      44,
#      4,
#      '9:35 PM',
#      '7:57',
#      "MISS Jefferson 1' Reverse Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      484,
#      4,
#      0,
#      4,
#      '9:35 PM',
#      '7:55',
#      None,
#      None,
#      'Holiday REBOUND (Off:1 Def:5)',
#      None,
#      None],
#     ['0021600001',
#      485,
#      2,
#      1,
#      4,
#      '9:35 PM',
#      '7:50',
#      None,
#      None,
#      "MISS Jennings 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      486,
#      4,
#      0,
#      4,
#      '9:35 PM',
#      '7:48',
#      'Liggins REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      487,
#      6,
#      2,
#      4,
#      '9:35 PM',
#      '7:48',
#      None,
#      None,
#      'Porzingis S.FOUL (P4.T3) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      488,
#      3,
#      11,
#      4,
#      '9:36 PM',
#      '7:48',
#      'Jefferson Free Throw 1 of 2 (10 PTS)',
#      None,
#      None,
#      '74 - 93',
#      '19'],
#     ['0021600001',
#      490,
#      8,
#      0,
#      4,
#      '9:36 PM',
#      '7:48',
#      'SUB: Love FOR Frye',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      491,
#      3,
#      12,
#      4,
#      '9:36 PM',
#      '7:48',
#      'MISS Jefferson Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      493,
#      4,
#      0,
#      4,
#      '9:36 PM',
#      '7:47',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      494,
#      6,
#      1,
#      4,
#      '9:36 PM',
#      '7:47',
#      None,
#      None,
#      'Anthony P.FOUL (P4.T4) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      495,
#      8,
#      0,
#      4,
#      '9:37 PM',
#      '7:47',
#      'SUB: Thompson FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      496,
#      6,
#      1,
#      4,
#      '9:37 PM',
#      '7:47',
#      None,
#      None,
#      'Anthony P.FOUL (P5.PN) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      497,
#      3,
#      11,
#      4,
#      '9:37 PM',
#      '7:47',
#      'Love Free Throw 1 of 2 (16 PTS)',
#      None,
#      None,
#      '74 - 94',
#      '20'],
#     ['0021600001',
#      499,
#      3,
#      12,
#      4,
#      '9:37 PM',
#      '7:47',
#      'MISS Love Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      501,
#      4,
#      0,
#      4,
#      '9:37 PM',
#      '7:46',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:4)',
#      None,
#      None],
#     ['0021600001',
#      502,
#      2,
#      1,
#      4,
#      '9:38 PM',
#      '7:33',
#      None,
#      None,
#      "MISS Anthony 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      503,
#      4,
#      0,
#      4,
#      '9:38 PM',
#      '7:33',
#      'James REBOUND (Off:3 Def:6)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      505,
#      6,
#      27,
#      4,
#      '9:38 PM',
#      '7:29',
#      None,
#      None,
#      'Porzingis Personal Block Foul (P5.PN) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      506,
#      3,
#      11,
#      4,
#      '9:38 PM',
#      '7:29',
#      'Love Free Throw 1 of 2 (17 PTS)',
#      None,
#      None,
#      '74 - 95',
#      '21'],
#     ['0021600001',
#      508,
#      3,
#      12,
#      4,
#      '9:38 PM',
#      '7:29',
#      'Love Free Throw 2 of 2 (18 PTS)',
#      None,
#      None,
#      '74 - 96',
#      '22'],
#     ['0021600001',
#      510,
#      2,
#      47,
#      4,
#      '9:39 PM',
#      '7:10',
#      None,
#      None,
#      "MISS Porzingis 13' Turnaround Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      511,
#      4,
#      0,
#      4,
#      '9:39 PM',
#      '7:08',
#      'James REBOUND (Off:3 Def:7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      513,
#      5,
#      1,
#      4,
#      '9:39 PM',
#      '6:53',
#      'James Bad Pass Turnover (P4.T14)',
#      None,
#      'Anthony STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      514,
#      2,
#      1,
#      4,
#      '9:39 PM',
#      '6:47',
#      None,
#      None,
#      "MISS Anthony 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      515,
#      4,
#      0,
#      4,
#      '9:39 PM',
#      '6:45',
#      'James REBOUND (Off:3 Def:8)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      516,
#      6,
#      1,
#      4,
#      '9:39 PM',
#      '6:44',
#      None,
#      None,
#      'Jennings P.FOUL (P2.PN) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      517,
#      3,
#      11,
#      4,
#      '9:40 PM',
#      '6:44',
#      'Love Free Throw 1 of 2 (19 PTS)',
#      None,
#      None,
#      '74 - 97',
#      '23'],
#     ['0021600001',
#      520,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      'SUB: Jefferson FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      521,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      None,
#      None,
#      'SUB: Baker FOR Rose',
#      None,
#      None],
#     ['0021600001',
#      522,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      None,
#      None,
#      "SUB: O'Quinn FOR Anthony",
#      None,
#      None],
#     ['0021600001',
#      523,
#      3,
#      12,
#      4,
#      '9:40 PM',
#      '6:44',
#      'Love Free Throw 2 of 2 (20 PTS)',
#      None,
#      None,
#      '74 - 98',
#      '24'],
#     ['0021600001',
#      525,
#      1,
#      80,
#      4,
#      '9:41 PM',
#      '6:22',
#      None,
#      None,
#      "Jennings 7' Step Back Jump Shot (7 PTS)",
#      '76 - 98',
#      '22'],
#     ['0021600001',
#      526,
#      1,
#      1,
#      4,
#      '9:41 PM',
#      '5:56',
#      "Jefferson 26' 3PT Jump Shot (13 PTS)",
#      None,
#      None,
#      '76 - 101',
#      '25'],
#     ['0021600001',
#      527,
#      2,
#      1,
#      4,
#      '9:41 PM',
#      '5:48',
#      None,
#      None,
#      "MISS Porzingis 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      528,
#      4,
#      0,
#      4,
#      '9:41 PM',
#      '5:48',
#      'Dunleavy REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      529,
#      1,
#      5,
#      4,
#      '9:41 PM',
#      '5:34',
#      "Love 1' Layup (22 PTS) (Liggins 1 AST)",
#      None,
#      None,
#      '76 - 103',
#      '27'],
#     ['0021600001',
#      530,
#      6,
#      2,
#      4,
#      '9:41 PM',
#      '5:34',
#      None,
#      None,
#      "O'Quinn S.FOUL (P3.PN) (B.Kennedy)",
#      None,
#      None],
#     ['0021600001',
#      531,
#      9,
#      4,
#      4,
#      '9:42 PM',
#      '5:34',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      535,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      None,
#      None,
#      'SUB: Hernangomez FOR Porzingis',
#      None,
#      None],
#     ['0021600001',
#      536,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      None,
#      None,
#      'SUB: Kuzminskas FOR Holiday',
#      None,
#      None],
#     ['0021600001',
#      537,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      'SUB: Andersen FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      538,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      'SUB: McRae FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      539,
#      3,
#      10,
#      4,
#      '9:45 PM',
#      '5:34',
#      'Love Free Throw 1 of 1 (23 PTS)',
#      None,
#      None,
#      '76 - 104',
#      '28'],
#     ['0021600001',
#      542,
#      6,
#      1,
#      4,
#      '9:45 PM',
#      '5:32',
#      'Liggins P.FOUL (P1.T3) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      543,
#      8,
#      0,
#      4,
#      '9:45 PM',
#      '5:30',
#      'SUB: Jones FOR Love',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      544,
#      2,
#      79,
#      4,
#      '9:45 PM',
#      '5:22',
#      None,
#      None,
#      "MISS Jennings 17' Pullup Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      545,
#      4,
#      0,
#      4,
#      '9:45 PM',
#      '5:21',
#      'Dunleavy REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      546,
#      1,
#      1,
#      4,
#      '9:45 PM',
#      '5:07',
#      "Jones 25' 3PT Jump Shot (3 PTS) (Dunleavy 2 AST)",
#      None,
#      None,
#      '76 - 107',
#      '31'],
#     ['0021600001',
#      548,
#      1,
#      82,
#      4,
#      '9:46 PM',
#      '4:48',
#      None,
#      None,
#      "Baker 10' Driving Bank Shot (2 PTS) (Jennings 3 AST)",
#      '78 - 107',
#      '29'],
#     ['0021600001',
#      549,
#      1,
#      79,
#      4,
#      '9:46 PM',
#      '4:30',
#      "McRae 9' Pullup Jump Shot (2 PTS) (Liggins 2 AST)",
#      None,
#      None,
#      '78 - 109',
#      '31'],
#     ['0021600001',
#      550,
#      1,
#      78,
#      4,
#      '9:46 PM',
#      '4:20',
#      None,
#      None,
#      "Kuzminskas 12' Floating Jump Shot (7 PTS) (Jennings 4 AST)",
#      '80 - 109',
#      '29'],
#     ['0021600001',
#      551,
#      2,
#      42,
#      4,
#      '9:47 PM',
#      '3:59',
#      "MISS McRae 1' Driving Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      552,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:57',
#      None,
#      None,
#      'Baker REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      553,
#      2,
#      1,
#      4,
#      '9:47 PM',
#      '3:49',
#      'Andersen BLOCK (1 BLK)',
#      None,
#      "MISS Baker 4' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      554,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:48',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:1)",
#      None,
#      None],
#     ['0021600001',
#      555,
#      1,
#      72,
#      4,
#      '9:47 PM',
#      '3:47',
#      None,
#      None,
#      "O'Quinn 1' Putback Layup (2 PTS)",
#      '82 - 109',
#      '27'],
#     ['0021600001',
#      556,
#      2,
#      1,
#      4,
#      '9:47 PM',
#      '3:33',
#      "MISS Liggins 10' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      557,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:32',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:2)",
#      None,
#      None],
#     ['0021600001',
#      558,
#      1,
#      5,
#      4,
#      '9:47 PM',
#      '3:26',
#      None,
#      None,
#      "Hernangomez 3' Layup (4 PTS) (Jennings 5 AST)",
#      '84 - 109',
#      '25'],
#     ['0021600001',
#      560,
#      2,
#      1,
#      4,
#      '9:48 PM',
#      '2:58',
#      "MISS Jones 22' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      561,
#      4,
#      0,
#      4,
#      '9:48 PM',
#      '2:57',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:3)",
#      None,
#      None],
#     ['0021600001',
#      562,
#      5,
#      1,
#      4,
#      '9:48 PM',
#      '2:55',
#      'Dunleavy STEAL (2 STL)',
#      None,
#      'Jennings Bad Pass Turnover (P1.T17)',
#      None,
#      None],
#     ['0021600001',
#      563,
#      1,
#      42,
#      4,
#      '9:48 PM',
#      '2:44',
#      "Liggins 1' Driving Layup (4 PTS)",
#      None,
#      None,
#      '84 - 111',
#      '27'],
#     ['0021600001',
#      564,
#      2,
#      1,
#      4,
#      '9:48 PM',
#      '2:30',
#      None,
#      None,
#      "MISS O'Quinn 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      565,
#      4,
#      0,
#      4,
#      '9:48 PM',
#      '2:29',
#      'Liggins REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      566,
#      5,
#      45,
#      4,
#      '9:48 PM',
#      '2:27',
#      'Liggins Out of Bounds - Bad Pass Turnover Turnover (P1.T15)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      567,
#      9,
#      1,
#      4,
#      '9:48 PM',
#      '2:27',
#      'CAVALIERS Timeout: Regular (Full 4 Short 1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      569,
#      8,
#      0,
#      4,
#      '9:51 PM',
#      '2:27',
#      None,
#      None,
#      'SUB: Vujacic FOR Jennings',
#      None,
#      None],
#     ['0021600001',
#      571,
#      6,
#      1,
#      4,
#      '9:51 PM',
#      '2:20',
#      'McRae P.FOUL (P1.T4) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      572,
#      2,
#      1,
#      4,
#      '9:52 PM',
#      '2:06',
#      None,
#      None,
#      "MISS Kuzminskas 26' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      573,
#      4,
#      0,
#      4,
#      '9:52 PM',
#      '2:06',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      574,
#      6,
#      3,
#      4,
#      '9:52 PM',
#      '2:06',
#      None,
#      None,
#      'Hernangomez L.B.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      575,
#      3,
#      11,
#      4,
#      '9:52 PM',
#      '2:06',
#      'Jones Free Throw 1 of 2 (4 PTS)',
#      None,
#      None,
#      '84 - 112',
#      '28'],
#     ['0021600001',
#      577,
#      3,
#      12,
#      4,
#      '9:52 PM',
#      '2:06',
#      'Jones Free Throw 2 of 2 (5 PTS)',
#      None,
#      None,
#      '84 - 113',
#      '29'],
#     ['0021600001',
#      579,
#      2,
#      98,
#      4,
#      '9:53 PM',
#      '1:50',
#      None,
#      None,
#      "MISS Hernangomez 2' Cutting Layup Shot",
#      None,
#      None],
#     ['0021600001',
#      580,
#      4,
#      0,
#      4,
#      '9:53 PM',
#      '1:50',
#      'Liggins REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      581,
#      2,
#      101,
#      4,
#      '9:53 PM',
#      '1:33',
#      "MISS McRae 7' Driving Floating Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      582,
#      4,
#      0,
#      4,
#      '9:53 PM',
#      '1:33',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:4)",
#      None,
#      None],
#     ['0021600001',
#      585,
#      5,
#      1,
#      4,
#      '9:54 PM',
#      '1:18',
#      'Dunleavy STEAL (3 STL)',
#      None,
#      'Vujacic Bad Pass Turnover (P1.T18)',
#      None,
#      None],
#     ['0021600001',
#      586,
#      1,
#      75,
#      4,
#      '9:54 PM',
#      '1:08',
#      'Dunleavy  Driving Finger Roll Layup (4 PTS) (Liggins 3 AST)',
#      None,
#      None,
#      '84 - 115',
#      '31'],
#     ['0021600001',
#      587,
#      6,
#      1,
#      4,
#      '9:54 PM',
#      '1:08',
#      'Jones P.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      588,
#      3,
#      11,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'MISS Vujacic Free Throw 1 of 2',
#      None,
#      None],
#     ['0021600001',
#      589,
#      4,
#      1,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      590,
#      3,
#      12,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'Vujacic Free Throw 2 of 2 (1 PTS)',
#      '85 - 115',
#      '30'],
#     ['0021600001',
#      593,
#      2,
#      79,
#      4,
#      '9:55 PM',
#      '0:47',
#      "MISS McRae 16' Pullup Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      594,
#      4,
#      0,
#      4,
#      '9:55 PM',
#      '0:47',
#      None,
#      None,
#      'Kuzminskas REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      595,
#      2,
#      1,
#      4,
#      '9:55 PM',
#      '0:36',
#      None,
#      None,
#      "MISS Vujacic 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      596,
#      4,
#      0,
#      4,
#      '9:55 PM',
#      '0:35',
#      'Dunleavy REBOUND (Off:0 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      597,
#      1,
#      79,
#      4,
#      '9:55 PM',
#      '0:19',
#      "Andersen 17' Pullup Jump Shot (2 PTS)",
#      None,
#      None,
#      '85 - 117',
#      '32'],
#     ['0021600001',
#      598,
#      1,
#      1,
#      4,
#      '9:56 PM',
#      '0:12',
#      None,
#      None,
#      "Baker 28' 3PT Jump Shot (5 PTS) (Vujacic 1 AST)",
#      '88 - 117',
#      '29'],
#     ['0021600001',
#      600,
#      13,
#      0,
#      4,
#      '9:56 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '88 - 117',
#      '29']]},
#   {'headers': ['VIDEO_AVAILABLE_FLAG'],
#    'name': 'AvailableVideo',
#    'rowSet': [[1]]}]}

# %%
response = player.PlayerGameLogs(2544,season='2017-18')
response.json
# Out:
# {'parameters': {'DateFrom': None,
#   'DateTo': None,
#   'LeagueID': '00',
#   'PlayerID': 2544,
#   'Season': '2017-18',
#   'SeasonType': 'Regular Season'},
#  'resource': 'playergamelog',
#  'resultSets': [{'headers': ['SEASON_ID',
#     'Player_ID',
#     'Game_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS',
#     'PLUS_MINUS',
#     'VIDEO_AVAILABLE'],
#    'name': 'PlayerGameLog',
#    'rowSet': [['22017',
#      2544,
#      '0021701220',
#      'APR 11, 2018',
#      'CLE vs. NYK',
#      'L',
#      11,
#      4,
#      9,
#      0.444,
#      0,
#      2,
#      0.0,
#      2,
#      3,
#      0.667,
#      1,
#      4,
#      5,
#      2,
#      1,
#      0,
#      3,
#      0,
#      10,
#      5,
#      1],
#     ['22017',
#      2544,
#      '0021701207',
#      'APR 09, 2018',
#      'CLE @ NYK',
#      'W',
#      39,
#      7,
#      16,
#      0.438,
#      3,
#      6,
#      0.5,
#      9,
#      10,
#      0.9,
#      0,
#      6,
#      6,
#      11,
#      1,
#      0,
#      4,
#      2,
#      26,
#      13,
#      1],
#     ['22017',
#      2544,
#      '0021701183',
#      'APR 06, 2018',
#      'CLE @ PHI',
#      'L',
#      40,
#      17,
#      29,
#      0.586,
#      4,
#      8,
#      0.5,
#      6,
#      11,
#      0.545,
#      1,
#      10,
#      11,
#      11,
#      2,
#      1,
#      8,
#      0,
#      44,
#      7,
#      1],
#     ['22017',
#      2544,
#      '0021701176',
#      'APR 05, 2018',
#      'CLE vs. WAS',
#      'W',
#      39,
#      12,
#      20,
#      0.6,
#      2,
#      7,
#      0.286,
#      7,
#      10,
#      0.7,
#      2,
#      7,
#      9,
#      14,
#      0,
#      0,
#      6,
#      2,
#      33,
#      13,
#      1],
#     ['22017',
#      2544,
#      '0021701156',
#      'APR 03, 2018',
#      'CLE vs. TOR',
#      'W',
#      37,
#      8,
#      14,
#      0.571,
#      3,
#      6,
#      0.5,
#      8,
#      11,
#      0.727,
#      0,
#      10,
#      10,
#      6,
#      0,
#      0,
#      5,
#      2,
#      27,
#      12,
#      1],
#     ['22017',
#      2544,
#      '0021701149',
#      'APR 01, 2018',
#      'CLE vs. DAL',
#      'W',
#      39,
#      5,
#      21,
#      0.238,
#      2,
#      3,
#      0.667,
#      4,
#      4,
#      1.0,
#      3,
#      10,
#      13,
#      12,
#      0,
#      0,
#      2,
#      1,
#      16,
#      7,
#      1],
#     ['22017',
#      2544,
#      '0021701131',
#      'MAR 30, 2018',
#      'CLE vs. NOP',
#      'W',
#      42,
#      12,
#      24,
#      0.5,
#      0,
#      4,
#      0.0,
#      3,
#      3,
#      1.0,
#      1,
#      8,
#      9,
#      11,
#      1,
#      0,
#      1,
#      0,
#      27,
#      16,
#      1],
#     ['22017',
#      2544,
#      '0021701116',
#      'MAR 28, 2018',
#      'CLE @ CHA',
#      'W',
#      37,
#      14,
#      26,
#      0.538,
#      4,
#      8,
#      0.5,
#      9,
#      11,
#      0.818,
#      2,
#      8,
#      10,
#      8,
#      1,
#      0,
#      4,
#      1,
#      41,
#      21,
#      1],
#     ['22017',
#      2544,
#      '0021701110',
#      'MAR 27, 2018',
#      'CLE @ MIA',
#      'L',
#      38,
#      7,
#      18,
#      0.389,
#      0,
#      4,
#      0.0,
#      4,
#      5,
#      0.8,
#      1,
#      5,
#      6,
#      7,
#      0,
#      0,
#      6,
#      1,
#      18,
#      -19,
#      1],
#     ['22017',
#      2544,
#      '0021701094',
#      'MAR 25, 2018',
#      'CLE @ BKN',
#      'W',
#      38,
#      14,
#      19,
#      0.737,
#      1,
#      4,
#      0.25,
#      8,
#      10,
#      0.8,
#      2,
#      8,
#      10,
#      8,
#      1,
#      0,
#      2,
#      3,
#      37,
#      11,
#      1],
#     ['22017',
#      2544,
#      '0021701080',
#      'MAR 23, 2018',
#      'CLE vs. PHX',
#      'W',
#      29,
#      11,
#      16,
#      0.688,
#      1,
#      4,
#      0.25,
#      4,
#      6,
#      0.667,
#      0,
#      6,
#      6,
#      9,
#      1,
#      1,
#      4,
#      3,
#      27,
#      11,
#      1],
#     ['22017',
#      2544,
#      '0021701065',
#      'MAR 21, 2018',
#      'CLE vs. TOR',
#      'W',
#      39,
#      11,
#      19,
#      0.579,
#      1,
#      3,
#      0.333,
#      12,
#      14,
#      0.857,
#      1,
#      6,
#      7,
#      17,
#      1,
#      0,
#      0,
#      2,
#      35,
#      12,
#      1],
#     ['22017',
#      2544,
#      '0021701050',
#      'MAR 19, 2018',
#      'CLE vs. MIL',
#      'W',
#      40,
#      16,
#      29,
#      0.552,
#      3,
#      7,
#      0.429,
#      5,
#      8,
#      0.625,
#      5,
#      7,
#      12,
#      10,
#      2,
#      1,
#      6,
#      2,
#      40,
#      4,
#      1],
#     ['22017',
#      2544,
#      '0021701039',
#      'MAR 17, 2018',
#      'CLE @ CHI',
#      'W',
#      40,
#      15,
#      26,
#      0.577,
#      2,
#      8,
#      0.25,
#      1,
#      4,
#      0.25,
#      1,
#      12,
#      13,
#      12,
#      1,
#      2,
#      6,
#      3,
#      33,
#      -4,
#      1],
#     ['22017',
#      2544,
#      '0021701028',
#      'MAR 15, 2018',
#      'CLE @ POR',
#      'L',
#      41,
#      15,
#      25,
#      0.6,
#      1,
#      4,
#      0.25,
#      4,
#      9,
#      0.444,
#      0,
#      14,
#      14,
#      6,
#      2,
#      3,
#      6,
#      4,
#      35,
#      -3,
#      1],
#     ['22017',
#      2544,
#      '0021701014',
#      'MAR 13, 2018',
#      'CLE @ PHX',
#      'W',
#      33,
#      7,
#      14,
#      0.5,
#      1,
#      2,
#      0.5,
#      13,
#      15,
#      0.867,
#      0,
#      12,
#      12,
#      11,
#      3,
#      2,
#      5,
#      2,
#      28,
#      23,
#      1],
#     ['22017',
#      2544,
#      '0021701000',
#      'MAR 11, 2018',
#      'CLE @ LAL',
#      'L',
#      31,
#      9,
#      20,
#      0.45,
#      2,
#      8,
#      0.25,
#      4,
#      5,
#      0.8,
#      2,
#      8,
#      10,
#      7,
#      1,
#      1,
#      2,
#      0,
#      24,
#      -13,
#      1],
#     ['22017',
#      2544,
#      '0021700986',
#      'MAR 09, 2018',
#      'CLE @ LAC',
#      'L',
#      39,
#      11,
#      20,
#      0.55,
#      3,
#      7,
#      0.429,
#      0,
#      2,
#      0.0,
#      0,
#      10,
#      10,
#      6,
#      2,
#      3,
#      5,
#      2,
#      25,
#      -16,
#      1],
#     ['22017',
#      2544,
#      '0021700970',
#      'MAR 07, 2018',
#      'CLE @ DEN',
#      'W',
#      39,
#      15,
#      25,
#      0.6,
#      5,
#      8,
#      0.625,
#      4,
#      8,
#      0.5,
#      1,
#      7,
#      8,
#      10,
#      1,
#      0,
#      3,
#      2,
#      39,
#      8,
#      1],
#     ['22017',
#      2544,
#      '0021700950',
#      'MAR 05, 2018',
#      'CLE vs. DET',
#      'W',
#      29,
#      11,
#      17,
#      0.647,
#      5,
#      7,
#      0.714,
#      4,
#      6,
#      0.667,
#      2,
#      5,
#      7,
#      7,
#      1,
#      0,
#      3,
#      2,
#      31,
#      14,
#      1],
#     ['22017',
#      2544,
#      '0021700937',
#      'MAR 03, 2018',
#      'CLE vs. DEN',
#      'L',
#      42,
#      8,
#      19,
#      0.421,
#      1,
#      4,
#      0.25,
#      8,
#      11,
#      0.727,
#      1,
#      9,
#      10,
#      15,
#      2,
#      0,
#      3,
#      2,
#      25,
#      -6,
#      1],
#     ['22017',
#      2544,
#      '0021700923',
#      'MAR 01, 2018',
#      'CLE vs. PHI',
#      'L',
#      39,
#      12,
#      24,
#      0.5,
#      2,
#      6,
#      0.333,
#      4,
#      6,
#      0.667,
#      1,
#      8,
#      9,
#      8,
#      1,
#      0,
#      3,
#      2,
#      30,
#      -8,
#      1],
#     ['22017',
#      2544,
#      '0021700908',
#      'FEB 27, 2018',
#      'CLE vs. BKN',
#      'W',
#      39,
#      13,
#      25,
#      0.52,
#      2,
#      4,
#      0.5,
#      3,
#      3,
#      1.0,
#      4,
#      8,
#      12,
#      11,
#      1,
#      0,
#      1,
#      1,
#      31,
#      2,
#      1],
#     ['22017',
#      2544,
#      '0021700894',
#      'FEB 25, 2018',
#      'CLE vs. SAS',
#      'L',
#      40,
#      14,
#      25,
#      0.56,
#      2,
#      5,
#      0.4,
#      3,
#      4,
#      0.75,
#      2,
#      11,
#      13,
#      9,
#      1,
#      0,
#      6,
#      3,
#      33,
#      -8,
#      1],
#     ['22017',
#      2544,
#      '0021700878',
#      'FEB 23, 2018',
#      'CLE @ MEM',
#      'W',
#      37,
#      7,
#      16,
#      0.438,
#      0,
#      2,
#      0.0,
#      4,
#      4,
#      1.0,
#      0,
#      14,
#      14,
#      11,
#      1,
#      0,
#      3,
#      0,
#      18,
#      18,
#      1],
#     ['22017',
#      2544,
#      '0021700869',
#      'FEB 22, 2018',
#      'CLE vs. WAS',
#      'L',
#      37,
#      13,
#      18,
#      0.722,
#      1,
#      4,
#      0.25,
#      5,
#      9,
#      0.556,
#      1,
#      8,
#      9,
#      8,
#      2,
#      0,
#      4,
#      2,
#      32,
#      -10,
#      1],
#     ['22017',
#      2544,
#      '0021700850',
#      'FEB 13, 2018',
#      'CLE @ OKC',
#      'W',
#      40,
#      14,
#      23,
#      0.609,
#      3,
#      7,
#      0.429,
#      6,
#      10,
#      0.6,
#      0,
#      8,
#      8,
#      8,
#      0,
#      1,
#      5,
#      1,
#      37,
#      -1,
#      1],
#     ['22017',
#      2544,
#      '0021700835',
#      'FEB 11, 2018',
#      'CLE @ BOS',
#      'W',
#      28,
#      9,
#      20,
#      0.45,
#      2,
#      5,
#      0.4,
#      4,
#      7,
#      0.571,
#      0,
#      8,
#      8,
#      10,
#      1,
#      1,
#      2,
#      1,
#      24,
#      23,
#      1],
#     ['22017',
#      2544,
#      '0021700819',
#      'FEB 09, 2018',
#      'CLE @ ATL',
#      'W',
#      41,
#      8,
#      20,
#      0.4,
#      0,
#      3,
#      0.0,
#      6,
#      7,
#      0.857,
#      2,
#      10,
#      12,
#      19,
#      0,
#      0,
#      3,
#      2,
#      22,
#      12,
#      1],
#     ['22017',
#      2544,
#      '0021700807',
#      'FEB 07, 2018',
#      'CLE vs. MIN',
#      'W',
#      48,
#      16,
#      22,
#      0.727,
#      5,
#      7,
#      0.714,
#      0,
#      2,
#      0.0,
#      1,
#      9,
#      10,
#      15,
#      1,
#      1,
#      5,
#      3,
#      37,
#      -1,
#      1],
#     ['22017',
#      2544,
#      '0021700797',
#      'FEB 06, 2018',
#      'CLE @ ORL',
#      'L',
#      33,
#      10,
#      17,
#      0.588,
#      2,
#      4,
#      0.5,
#      3,
#      4,
#      0.75,
#      1,
#      9,
#      10,
#      5,
#      1,
#      0,
#      6,
#      4,
#      25,
#      -14,
#      1],
#     ['22017',
#      2544,
#      '0021700779',
#      'FEB 03, 2018',
#      'CLE vs. HOU',
#      'L',
#      31,
#      3,
#      10,
#      0.3,
#      1,
#      2,
#      0.5,
#      4,
#      4,
#      1.0,
#      1,
#      8,
#      9,
#      9,
#      2,
#      1,
#      2,
#      0,
#      11,
#      -17,
#      1],
#     ['22017',
#      2544,
#      '0021700757',
#      'JAN 31, 2018',
#      'CLE vs. MIA',
#      'W',
#      38,
#      8,
#      21,
#      0.381,
#      1,
#      6,
#      0.167,
#      7,
#      11,
#      0.636,
#      2,
#      9,
#      11,
#      5,
#      1,
#      0,
#      7,
#      1,
#      24,
#      3,
#      1],
#     ['22017',
#      2544,
#      '0021700747',
#      'JAN 30, 2018',
#      'CLE @ DET',
#      'L',
#      38,
#      9,
#      20,
#      0.45,
#      2,
#      7,
#      0.286,
#      1,
#      2,
#      0.5,
#      0,
#      6,
#      6,
#      7,
#      0,
#      1,
#      4,
#      2,
#      21,
#      -13,
#      1],
#     ['22017',
#      2544,
#      '0021700734',
#      'JAN 28, 2018',
#      'CLE vs. DET',
#      'W',
#      38,
#      8,
#      15,
#      0.533,
#      1,
#      4,
#      0.25,
#      8,
#      9,
#      0.889,
#      1,
#      7,
#      8,
#      14,
#      1,
#      0,
#      3,
#      0,
#      25,
#      18,
#      1],
#     ['22017',
#      2544,
#      '0021700715',
#      'JAN 26, 2018',
#      'CLE vs. IND',
#      'W',
#      40,
#      11,
#      17,
#      0.647,
#      0,
#      2,
#      0.0,
#      4,
#      5,
#      0.8,
#      0,
#      10,
#      10,
#      11,
#      4,
#      1,
#      11,
#      0,
#      26,
#      12,
#      1],
#     ['22017',
#      2544,
#      '0021700698',
#      'JAN 23, 2018',
#      'CLE @ SAS',
#      'L',
#      38,
#      10,
#      23,
#      0.435,
#      2,
#      6,
#      0.333,
#      6,
#      10,
#      0.6,
#      2,
#      7,
#      9,
#      7,
#      0,
#      1,
#      5,
#      0,
#      28,
#      -10,
#      1],
#     ['22017',
#      2544,
#      '0021700674',
#      'JAN 20, 2018',
#      'CLE vs. OKC',
#      'L',
#      38,
#      8,
#      17,
#      0.471,
#      0,
#      4,
#      0.0,
#      2,
#      4,
#      0.5,
#      0,
#      3,
#      3,
#      7,
#      0,
#      1,
#      2,
#      2,
#      18,
#      -33,
#      1],
#     ['22017',
#      2544,
#      '0021700664',
#      'JAN 18, 2018',
#      'CLE vs. ORL',
#      'W',
#      35,
#      7,
#      16,
#      0.438,
#      0,
#      4,
#      0.0,
#      2,
#      8,
#      0.25,
#      1,
#      4,
#      5,
#      6,
#      1,
#      0,
#      6,
#      1,
#      16,
#      -4,
#      1],
#     ['22017',
#      2544,
#      '0021700646',
#      'JAN 15, 2018',
#      'CLE vs. GSW',
#      'L',
#      36,
#      12,
#      18,
#      0.667,
#      0,
#      2,
#      0.0,
#      8,
#      13,
#      0.615,
#      2,
#      6,
#      8,
#      6,
#      3,
#      4,
#      8,
#      3,
#      32,
#      -14,
#      1],
#     ['22017',
#      2544,
#      '0021700619',
#      'JAN 12, 2018',
#      'CLE @ IND',
#      'L',
#      40,
#      11,
#      25,
#      0.44,
#      2,
#      9,
#      0.222,
#      3,
#      4,
#      0.75,
#      2,
#      6,
#      8,
#      11,
#      3,
#      1,
#      5,
#      2,
#      27,
#      -6,
#      1],
#     ['22017',
#      2544,
#      '0021700615',
#      'JAN 11, 2018',
#      'CLE @ TOR',
#      'L',
#      32,
#      9,
#      16,
#      0.563,
#      0,
#      1,
#      0.0,
#      8,
#      10,
#      0.8,
#      0,
#      3,
#      3,
#      1,
#      1,
#      2,
#      2,
#      1,
#      26,
#      -22,
#      1],
#     ['22017',
#      2544,
#      '0021700594',
#      'JAN 08, 2018',
#      'CLE @ MIN',
#      'L',
#      27,
#      4,
#      8,
#      0.5,
#      1,
#      3,
#      0.333,
#      1,
#      3,
#      0.333,
#      1,
#      7,
#      8,
#      5,
#      0,
#      2,
#      3,
#      2,
#      10,
#      -39,
#      1],
#     ['22017',
#      2544,
#      '0021700582',
#      'JAN 06, 2018',
#      'CLE @ ORL',
#      'W',
#      37,
#      12,
#      23,
#      0.522,
#      4,
#      7,
#      0.571,
#      5,
#      7,
#      0.714,
#      3,
#      7,
#      10,
#      9,
#      6,
#      1,
#      3,
#      1,
#      33,
#      15,
#      1],
#     ['22017',
#      2544,
#      '0021700559',
#      'JAN 03, 2018',
#      'CLE @ BOS',
#      'L',
#      33,
#      8,
#      15,
#      0.533,
#      0,
#      2,
#      0.0,
#      3,
#      3,
#      1.0,
#      0,
#      7,
#      7,
#      6,
#      1,
#      1,
#      4,
#      1,
#      19,
#      -6,
#      1],
#     ['22017',
#      2544,
#      '0021700549',
#      'JAN 02, 2018',
#      'CLE vs. POR',
#      'W',
#      34,
#      10,
#      17,
#      0.588,
#      0,
#      2,
#      0.0,
#      4,
#      4,
#      1.0,
#      1,
#      5,
#      6,
#      8,
#      4,
#      1,
#      3,
#      2,
#      24,
#      0,
#      1],
#     ['22017',
#      2544,
#      '0021700534',
#      'DEC 30, 2017',
#      'CLE @ UTA',
#      'L',
#      37,
#      12,
#      22,
#      0.545,
#      1,
#      7,
#      0.143,
#      4,
#      5,
#      0.8,
#      1,
#      7,
#      8,
#      6,
#      2,
#      1,
#      6,
#      1,
#      29,
#      -5,
#      1],
#     ['22017',
#      2544,
#      '0021700513',
#      'DEC 27, 2017',
#      'CLE @ SAC',
#      'L',
#      38,
#      6,
#      17,
#      0.353,
#      0,
#      2,
#      0.0,
#      4,
#      5,
#      0.8,
#      2,
#      8,
#      10,
#      14,
#      5,
#      0,
#      4,
#      2,
#      16,
#      -11,
#      1],
#     ['22017',
#      2544,
#      '0021700494',
#      'DEC 25, 2017',
#      'CLE @ GSW',
#      'L',
#      40,
#      7,
#      18,
#      0.389,
#      2,
#      7,
#      0.286,
#      4,
#      7,
#      0.571,
#      1,
#      5,
#      6,
#      6,
#      0,
#      0,
#      7,
#      2,
#      20,
#      -1,
#      1],
#     ['22017',
#      2544,
#      '0021700466',
#      'DEC 21, 2017',
#      'CLE vs. CHI',
#      'W',
#      39,
#      12,
#      23,
#      0.522,
#      2,
#      5,
#      0.4,
#      8,
#      8,
#      1.0,
#      1,
#      5,
#      6,
#      9,
#      3,
#      0,
#      4,
#      1,
#      34,
#      5,
#      1],
#     ['22017',
#      2544,
#      '0021700453',
#      'DEC 19, 2017',
#      'CLE @ MIL',
#      'L',
#      34,
#      14,
#      22,
#      0.636,
#      6,
#      11,
#      0.545,
#      5,
#      5,
#      1.0,
#      0,
#      1,
#      1,
#      7,
#      3,
#      2,
#      7,
#      1,
#      39,
#      -7,
#      1],
#     ['22017',
#      2544,
#      '0021700440',
#      'DEC 17, 2017',
#      'CLE @ WAS',
#      'W',
#      41,
#      8,
#      23,
#      0.348,
#      2,
#      7,
#      0.286,
#      2,
#      3,
#      0.667,
#      2,
#      9,
#      11,
#      15,
#      0,
#      1,
#      6,
#      4,
#      20,
#      4,
#      1],
#     ['22017',
#      2544,
#      '0021700430',
#      'DEC 16, 2017',
#      'CLE vs. UTA',
#      'W',
#      37,
#      9,
#      15,
#      0.6,
#      1,
#      4,
#      0.25,
#      10,
#      10,
#      1.0,
#      0,
#      11,
#      11,
#      10,
#      1,
#      0,
#      5,
#      2,
#      29,
#      0,
#      1],
#     ['22017',
#      2544,
#      '0021700415',
#      'DEC 14, 2017',
#      'CLE vs. LAL',
#      'W',
#      39,
#      8,
#      18,
#      0.444,
#      1,
#      6,
#      0.167,
#      8,
#      12,
#      0.667,
#      1,
#      11,
#      12,
#      12,
#      2,
#      2,
#      5,
#      0,
#      25,
#      14,
#      1],
#     ['22017',
#      2544,
#      '0021700397',
#      'DEC 12, 2017',
#      'CLE vs. ATL',
#      'W',
#      35,
#      11,
#      13,
#      0.846,
#      2,
#      3,
#      0.667,
#      1,
#      2,
#      0.5,
#      0,
#      7,
#      7,
#      17,
#      2,
#      0,
#      2,
#      4,
#      25,
#      19,
#      1],
#     ['22017',
#      2544,
#      '0021700379',
#      'DEC 09, 2017',
#      'CLE vs. PHI',
#      'W',
#      39,
#      9,
#      23,
#      0.391,
#      2,
#      6,
#      0.333,
#      10,
#      12,
#      0.833,
#      3,
#      10,
#      13,
#      13,
#      3,
#      0,
#      6,
#      1,
#      30,
#      -3,
#      1],
#     ['22017',
#      2544,
#      '0021700369',
#      'DEC 08, 2017',
#      'CLE @ IND',
#      'L',
#      39,
#      12,
#      22,
#      0.545,
#      1,
#      5,
#      0.2,
#      4,
#      5,
#      0.8,
#      2,
#      8,
#      10,
#      8,
#      1,
#      2,
#      3,
#      1,
#      29,
#      3,
#      1],
#     ['22017',
#      2544,
#      '0021700353',
#      'DEC 06, 2017',
#      'CLE vs. SAC',
#      'W',
#      41,
#      12,
#      18,
#      0.667,
#      5,
#      8,
#      0.625,
#      3,
#      6,
#      0.5,
#      2,
#      9,
#      11,
#      9,
#      3,
#      2,
#      7,
#      0,
#      32,
#      2,
#      1],
#     ['22017',
#      2544,
#      '0021700344',
#      'DEC 04, 2017',
#      'CLE @ CHI',
#      'W',
#      34,
#      9,
#      15,
#      0.6,
#      2,
#      4,
#      0.5,
#      3,
#      4,
#      0.75,
#      0,
#      7,
#      7,
#      6,
#      2,
#      0,
#      2,
#      1,
#      23,
#      27,
#      1],
#     ['22017',
#      2544,
#      '0021700329',
#      'DEC 02, 2017',
#      'CLE vs. MEM',
#      'W',
#      39,
#      13,
#      22,
#      0.591,
#      0,
#      3,
#      0.0,
#      8,
#      8,
#      1.0,
#      0,
#      2,
#      2,
#      12,
#      0,
#      1,
#      5,
#      1,
#      34,
#      -5,
#      1],
#     ['22017',
#      2544,
#      '0021700313',
#      'NOV 30, 2017',
#      'CLE @ ATL',
#      'W',
#      38,
#      8,
#      11,
#      0.727,
#      3,
#      6,
#      0.5,
#      5,
#      7,
#      0.714,
#      1,
#      5,
#      6,
#      12,
#      2,
#      2,
#      3,
#      3,
#      24,
#      10,
#      1],
#     ['22017',
#      2544,
#      '0021700298',
#      'NOV 28, 2017',
#      'CLE vs. MIA',
#      'W',
#      28,
#      10,
#      16,
#      0.625,
#      1,
#      3,
#      0.333,
#      0,
#      1,
#      0.0,
#      2,
#      10,
#      12,
#      6,
#      5,
#      1,
#      2,
#      1,
#      21,
#      26,
#      1],
#     ['22017',
#      2544,
#      '0021700291',
#      'NOV 27, 2017',
#      'CLE @ PHI',
#      'W',
#      31,
#      12,
#      23,
#      0.522,
#      3,
#      7,
#      0.429,
#      3,
#      4,
#      0.75,
#      3,
#      11,
#      14,
#      6,
#      0,
#      0,
#      3,
#      0,
#      30,
#      1,
#      1],
#     ['22017',
#      2544,
#      '0021700270',
#      'NOV 24, 2017',
#      'CLE vs. CHA',
#      'W',
#      40,
#      10,
#      20,
#      0.5,
#      3,
#      8,
#      0.375,
#      4,
#      7,
#      0.571,
#      1,
#      15,
#      16,
#      13,
#      0,
#      3,
#      3,
#      2,
#      27,
#      -2,
#      1],
#     ['22017',
#      2544,
#      '0021700254',
#      'NOV 22, 2017',
#      'CLE vs. BKN',
#      'W',
#      33,
#      11,
#      17,
#      0.647,
#      4,
#      7,
#      0.571,
#      7,
#      9,
#      0.778,
#      1,
#      5,
#      6,
#      5,
#      2,
#      0,
#      3,
#      2,
#      33,
#      20,
#      1],
#     ['22017',
#      2544,
#      '0021700242',
#      'NOV 20, 2017',
#      'CLE @ DET',
#      'W',
#      27,
#      7,
#      14,
#      0.5,
#      3,
#      5,
#      0.6,
#      1,
#      1,
#      1.0,
#      0,
#      2,
#      2,
#      8,
#      1,
#      1,
#      0,
#      2,
#      18,
#      21,
#      1],
#     ['22017',
#      2544,
#      '0021700220',
#      'NOV 17, 2017',
#      'CLE vs. LAC',
#      'W',
#      46,
#      17,
#      26,
#      0.654,
#      4,
#      9,
#      0.444,
#      1,
#      5,
#      0.2,
#      1,
#      13,
#      14,
#      6,
#      0,
#      0,
#      6,
#      0,
#      39,
#      1,
#      1],
#     ['22017',
#      2544,
#      '0021700207',
#      'NOV 15, 2017',
#      'CLE @ CHA',
#      'W',
#      37,
#      12,
#      24,
#      0.5,
#      4,
#      7,
#      0.571,
#      3,
#      3,
#      1.0,
#      2,
#      4,
#      6,
#      8,
#      2,
#      1,
#      3,
#      4,
#      31,
#      1,
#      1],
#     ['22017',
#      2544,
#      '0021700193',
#      'NOV 13, 2017',
#      'CLE @ NYK',
#      'W',
#      36,
#      7,
#      14,
#      0.5,
#      2,
#      4,
#      0.5,
#      7,
#      10,
#      0.7,
#      3,
#      6,
#      9,
#      12,
#      0,
#      3,
#      5,
#      1,
#      23,
#      3,
#      2],
#     ['22017',
#      2544,
#      '0021700181',
#      'NOV 11, 2017',
#      'CLE @ DAL',
#      'W',
#      42,
#      6,
#      14,
#      0.429,
#      1,
#      3,
#      0.333,
#      6,
#      8,
#      0.75,
#      1,
#      10,
#      11,
#      4,
#      0,
#      1,
#      6,
#      3,
#      19,
#      5,
#      1],
#     ['22017',
#      2544,
#      '0021700166',
#      'NOV 09, 2017',
#      'CLE @ HOU',
#      'L',
#      40,
#      15,
#      24,
#      0.625,
#      1,
#      4,
#      0.25,
#      2,
#      3,
#      0.667,
#      0,
#      4,
#      4,
#      7,
#      1,
#      1,
#      8,
#      4,
#      33,
#      5,
#      1],
#     ['22017',
#      2544,
#      '0021700149',
#      'NOV 07, 2017',
#      'CLE vs. MIL',
#      'W',
#      37,
#      10,
#      20,
#      0.5,
#      2,
#      4,
#      0.5,
#      8,
#      10,
#      0.8,
#      1,
#      7,
#      8,
#      9,
#      3,
#      0,
#      1,
#      1,
#      30,
#      6,
#      1],
#     ['22017',
#      2544,
#      '0021700136',
#      'NOV 05, 2017',
#      'CLE vs. ATL',
#      'L',
#      41,
#      10,
#      17,
#      0.588,
#      0,
#      3,
#      0.0,
#      6,
#      6,
#      1.0,
#      2,
#      3,
#      5,
#      13,
#      1,
#      2,
#      6,
#      4,
#      26,
#      -4,
#      1],
#     ['22017',
#      2544,
#      '0021700122',
#      'NOV 03, 2017',
#      'CLE @ WAS',
#      'W',
#      43,
#      23,
#      34,
#      0.676,
#      2,
#      4,
#      0.5,
#      9,
#      9,
#      1.0,
#      5,
#      6,
#      11,
#      7,
#      3,
#      2,
#      3,
#      2,
#      57,
#      6,
#      1],
#     ['22017',
#      2544,
#      '0021700106',
#      'NOV 01, 2017',
#      'CLE vs. IND',
#      'L',
#      37,
#      14,
#      22,
#      0.636,
#      1,
#      5,
#      0.2,
#      4,
#      5,
#      0.8,
#      1,
#      5,
#      6,
#      11,
#      2,
#      1,
#      8,
#      1,
#      33,
#      -12,
#      2],
#     ['22017',
#      2544,
#      '0021700090',
#      'OCT 29, 2017',
#      'CLE vs. NYK',
#      'L',
#      39,
#      7,
#      15,
#      0.467,
#      1,
#      4,
#      0.25,
#      1,
#      1,
#      1.0,
#      1,
#      9,
#      10,
#      7,
#      2,
#      0,
#      4,
#      2,
#      16,
#      -17,
#      1],
#     ['22017',
#      2544,
#      '0021700077',
#      'OCT 28, 2017',
#      'CLE @ NOP',
#      'L',
#      31,
#      6,
#      11,
#      0.545,
#      1,
#      3,
#      0.333,
#      5,
#      6,
#      0.833,
#      0,
#      3,
#      3,
#      8,
#      0,
#      0,
#      4,
#      3,
#      18,
#      -10,
#      1],
#     ['22017',
#      2544,
#      '0021700058',
#      'OCT 25, 2017',
#      'CLE @ BKN',
#      'L',
#      41,
#      12,
#      20,
#      0.6,
#      1,
#      2,
#      0.5,
#      4,
#      8,
#      0.5,
#      1,
#      9,
#      10,
#      13,
#      0,
#      4,
#      8,
#      1,
#      29,
#      -2,
#      1],
#     ['22017',
#      2544,
#      '0021700049',
#      'OCT 24, 2017',
#      'CLE vs. CHI',
#      'W',
#      37,
#      13,
#      20,
#      0.65,
#      4,
#      6,
#      0.667,
#      4,
#      5,
#      0.8,
#      0,
#      2,
#      2,
#      13,
#      3,
#      0,
#      2,
#      1,
#      34,
#      7,
#      2],
#     ['22017',
#      2544,
#      '0021700028',
#      'OCT 21, 2017',
#      'CLE vs. ORL',
#      'L',
#      31,
#      8,
#      15,
#      0.533,
#      1,
#      3,
#      0.333,
#      5,
#      6,
#      0.833,
#      0,
#      4,
#      4,
#      2,
#      1,
#      1,
#      1,
#      0,
#      22,
#      -31,
#      1],
#     ['22017',
#      2544,
#      '0021700021',
#      'OCT 20, 2017',
#      'CLE @ MIL',
#      'W',
#      37,
#      10,
#      16,
#      0.625,
#      2,
#      4,
#      0.5,
#      2,
#      2,
#      1.0,
#      1,
#      4,
#      5,
#      8,
#      1,
#      1,
#      5,
#      2,
#      24,
#      13,
#      1],
#     ['22017',
#      2544,
#      '0021700001',
#      'OCT 17, 2017',
#      'CLE vs. BOS',
#      'W',
#      41,
#      12,
#      19,
#      0.632,
#      1,
#      5,
#      0.2,
#      4,
#      4,
#      1.0,
#      1,
#      15,
#      16,
#      9,
#      0,
#      2,
#      4,
#      3,
#      29,
#      3,
#      1]]}]}

# %%
url = 'http://stats.nba.com/stats/playbyplayv2/?GameID=0021600002&EndPeriod=0&StartPeriod=0'
headers = {'host': 'stats.nba.com',
          'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.84 Safari/537.36',
          'cache-control': 'no-cache',
          'pragma': 'no-cache',
          'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
           'accept-encoding': 'gzip, deflate',
        'accept-language': 'en-US,en;q=0.9',
        'connection': 'keep-alive'}

r = requests.get(url,  headers=headers)
jsn = response.json

# %%
rjson = jsn['resultSets'][0]
headers= rjson['headers']
rowSet = rjson['rowSet']
rows = rowSet[1:]

df = pd.DataFrame(rows, columns=headers)
df.head()
jsn
# Out:
# {'parameters': {'EndPeriod': 0, 'GameID': '0021600001', 'StartPeriod': 0},
#  'resource': 'playbyplay',
#  'resultSets': [{'headers': ['GAME_ID',
#     'EVENTNUM',
#     'EVENTMSGTYPE',
#     'EVENTMSGACTIONTYPE',
#     'PERIOD',
#     'WCTIMESTRING',
#     'PCTIMESTRING',
#     'HOMEDESCRIPTION',
#     'NEUTRALDESCRIPTION',
#     'VISITORDESCRIPTION',
#     'SCORE',
#     'SCOREMARGIN'],
#    'name': 'PlayByPlay',
#    'rowSet': [['0021600001',
#      0,
#      12,
#      0,
#      1,
#      '7:37 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      1,
#      10,
#      0,
#      1,
#      '7:37 PM',
#      '12:00',
#      'Jump Ball Thompson vs. Noah: Tip to Rose',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      2,
#      1,
#      42,
#      1,
#      '7:37 PM',
#      '11:40',
#      None,
#      None,
#      "Rose 1' Driving Layup (2 PTS) (Noah 1 AST)",
#      '2 - 0',
#      '-2'],
#     ['0021600001',
#      3,
#      2,
#      3,
#      1,
#      '7:37 PM',
#      '11:26',
#      "MISS Love 4' Hook Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      4,
#      4,
#      0,
#      1,
#      '7:37 PM',
#      '11:23',
#      None,
#      None,
#      'Noah REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      5,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '11:16',
#      None,
#      None,
#      "MISS Anthony 20' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      6,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '11:15',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      7,
#      1,
#      97,
#      1,
#      '7:38 PM',
#      '11:15',
#      None,
#      None,
#      "Porzingis 2' Tip Layup Shot (2 PTS)",
#      '4 - 0',
#      '-4'],
#     ['0021600001',
#      8,
#      1,
#      1,
#      1,
#      '7:38 PM',
#      '10:59',
#      "James 11' Jump Shot (2 PTS) (Irving 1 AST)",
#      None,
#      None,
#      '4 - 2',
#      '-2'],
#     ['0021600001',
#      9,
#      5,
#      40,
#      1,
#      '7:38 PM',
#      '10:58',
#      None,
#      None,
#      'Rose Out of Bounds Lost Ball Turnover (P1.T1)',
#      None,
#      None],
#     ['0021600001',
#      10,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:46',
#      "MISS Irving 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      11,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '10:45',
#      None,
#      None,
#      'Lee REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      12,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:34',
#      None,
#      None,
#      "MISS Lee 18' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      13,
#      4,
#      0,
#      1,
#      '7:38 PM',
#      '10:33',
#      'Love REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      14,
#      2,
#      1,
#      1,
#      '7:38 PM',
#      '10:21',
#      "MISS Love 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      15,
#      4,
#      0,
#      1,
#      '7:39 PM',
#      '10:21',
#      None,
#      None,
#      'Noah REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      16,
#      6,
#      4,
#      1,
#      '7:39 PM',
#      '10:11',
#      None,
#      None,
#      'Noah OFF.Foul (P1) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      17,
#      5,
#      5,
#      1,
#      '7:39 PM',
#      '10:11',
#      None,
#      None,
#      'Noah Foul Turnover (P1.T2)',
#      None,
#      None],
#     ['0021600001',
#      18,
#      1,
#      98,
#      1,
#      '7:39 PM',
#      '9:59',
#      'Smith  Cutting Layup Shot (2 PTS) (James 1 AST)',
#      None,
#      None,
#      '4 - 4',
#      'TIE'],
#     ['0021600001',
#      19,
#      2,
#      1,
#      1,
#      '7:39 PM',
#      '9:47',
#      None,
#      None,
#      "MISS Porzingis 16' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      20,
#      4,
#      0,
#      1,
#      '7:39 PM',
#      '9:47',
#      None,
#      None,
#      'Noah REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      21,
#      6,
#      2,
#      1,
#      '7:40 PM',
#      '9:44',
#      'James S.FOUL (P1.T1) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      22,
#      3,
#      11,
#      1,
#      '7:40 PM',
#      '9:44',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (3 PTS)',
#      '5 - 4',
#      '-1'],
#     ['0021600001',
#      24,
#      3,
#      12,
#      1,
#      '7:40 PM',
#      '9:44',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      26,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:44',
#      'Thompson REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      27,
#      2,
#      1,
#      1,
#      '7:40 PM',
#      '9:33',
#      "MISS Love 20' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      28,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:32',
#      'Irving REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      29,
#      2,
#      1,
#      1,
#      '7:40 PM',
#      '9:27',
#      "MISS James 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      30,
#      4,
#      0,
#      1,
#      '7:40 PM',
#      '9:27',
#      None,
#      None,
#      'Noah REBOUND (Off:1 Def:3)',
#      None,
#      None],
#     ['0021600001',
#      31,
#      2,
#      78,
#      1,
#      '7:41 PM',
#      '9:18',
#      None,
#      None,
#      "MISS Rose 12' Floating Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      32,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:16',
#      None,
#      None,
#      'Rose REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      33,
#      2,
#      1,
#      1,
#      '7:41 PM',
#      '9:08',
#      None,
#      None,
#      "MISS Lee 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      34,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:07',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      35,
#      2,
#      97,
#      1,
#      '7:41 PM',
#      '9:07',
#      None,
#      None,
#      "MISS Anthony 1' Tip Layup Shot",
#      None,
#      None],
#     ['0021600001',
#      36,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '9:06',
#      'Love REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      37,
#      2,
#      47,
#      1,
#      '7:41 PM',
#      '8:58',
#      "MISS Thompson 9' Turnaround Jump Shot",
#      None,
#      'Porzingis BLOCK (1 BLK)',
#      None,
#      None],
#     ['0021600001',
#      38,
#      4,
#      0,
#      1,
#      '7:41 PM',
#      '8:56',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      39,
#      1,
#      1,
#      1,
#      '7:41 PM',
#      '8:47',
#      None,
#      None,
#      "Anthony 16' Jump Shot (2 PTS)",
#      '7 - 4',
#      '-3'],
#     ['0021600001',
#      40,
#      2,
#      1,
#      1,
#      '7:42 PM',
#      '8:16',
#      "MISS James 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      41,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:15',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      42,
#      2,
#      5,
#      1,
#      '7:42 PM',
#      '8:09',
#      None,
#      None,
#      "MISS Rose 1' Layup",
#      None,
#      None],
#     ['0021600001',
#      43,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:06',
#      'James REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      44,
#      2,
#      5,
#      1,
#      '7:42 PM',
#      '8:01',
#      'MISS Irving  Layup',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      45,
#      4,
#      0,
#      1,
#      '7:42 PM',
#      '8:01',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      46,
#      1,
#      1,
#      1,
#      '7:42 PM',
#      '7:56',
#      "Smith 25' 3PT Jump Shot (5 PTS) (James 2 AST)",
#      None,
#      None,
#      '7 - 7',
#      'TIE'],
#     ['0021600001',
#      47,
#      5,
#      1,
#      1,
#      '7:43 PM',
#      '7:42',
#      'Love STEAL (1 STL)',
#      None,
#      'Anthony Bad Pass Turnover (P1.T3)',
#      None,
#      None],
#     ['0021600001',
#      48,
#      2,
#      1,
#      1,
#      '7:43 PM',
#      '7:33',
#      "MISS Smith 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      49,
#      4,
#      0,
#      1,
#      '7:43 PM',
#      '7:32',
#      None,
#      None,
#      'Rose REBOUND (Off:1 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      51,
#      9,
#      1,
#      1,
#      '7:43 PM',
#      '7:28',
#      'CAVALIERS Timeout: Regular (Full 1 Short 0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      56,
#      1,
#      1,
#      1,
#      '7:46 PM',
#      '7:12',
#      None,
#      None,
#      'Anthony  3PT Jump Shot (5 PTS) (Rose 1 AST)',
#      '10 - 7',
#      '-3'],
#     ['0021600001',
#      57,
#      6,
#      1,
#      1,
#      '7:46 PM',
#      '7:03',
#      None,
#      None,
#      'Anthony P.FOUL (P1.T1) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      58,
#      2,
#      1,
#      1,
#      '7:47 PM',
#      '6:52',
#      "MISS Smith 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      59,
#      4,
#      0,
#      1,
#      '7:47 PM',
#      '6:52',
#      'James REBOUND (Off:1 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      60,
#      1,
#      42,
#      1,
#      '7:47 PM',
#      '6:48',
#      "Love 2' Driving Layup (2 PTS) (James 3 AST)",
#      None,
#      None,
#      '10 - 9',
#      '-1'],
#     ['0021600001',
#      61,
#      6,
#      2,
#      1,
#      '7:47 PM',
#      '6:48',
#      None,
#      None,
#      'Porzingis S.FOUL (P1.T2) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      62,
#      3,
#      10,
#      1,
#      '7:47 PM',
#      '6:48',
#      'Love Free Throw 1 of 1 (3 PTS)',
#      None,
#      None,
#      '10 - 10',
#      'TIE'],
#     ['0021600001',
#      65,
#      2,
#      5,
#      1,
#      '7:48 PM',
#      '6:24',
#      None,
#      None,
#      'MISS Noah  Layup',
#      None,
#      None],
#     ['0021600001',
#      66,
#      4,
#      0,
#      1,
#      '7:48 PM',
#      '6:24',
#      'Smith REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      67,
#      1,
#      1,
#      1,
#      '7:48 PM',
#      '6:13',
#      "Irving 15' Jump Shot (2 PTS) (James 4 AST)",
#      None,
#      None,
#      '10 - 12',
#      '2'],
#     ['0021600001',
#      68,
#      5,
#      2,
#      1,
#      '7:48 PM',
#      '6:02',
#      'Irving STEAL (1 STL)',
#      None,
#      'Rose Lost Ball Turnover (P2.T4)',
#      None,
#      None],
#     ['0021600001',
#      69,
#      1,
#      41,
#      1,
#      '7:48 PM',
#      '5:56',
#      "James 1' Running Layup (4 PTS) (Love 1 AST)",
#      None,
#      None,
#      '10 - 14',
#      '4'],
#     ['0021600001',
#      70,
#      1,
#      1,
#      1,
#      '7:48 PM',
#      '5:38',
#      None,
#      None,
#      "Anthony 23' Jump Shot (7 PTS)",
#      '12 - 14',
#      '2'],
#     ['0021600001',
#      71,
#      2,
#      42,
#      1,
#      '7:49 PM',
#      '5:25',
#      "MISS Irving 2' Driving Layup",
#      None,
#      'Rose BLOCK (1 BLK)',
#      None,
#      None],
#     ['0021600001',
#      72,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      74,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      'SUB: Jefferson FOR Love',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      75,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      None,
#      None,
#      'SUB: Jennings FOR Rose',
#      None,
#      None],
#     ['0021600001',
#      76,
#      8,
#      0,
#      1,
#      '7:49 PM',
#      '5:25',
#      None,
#      None,
#      "SUB: O'Quinn FOR Noah",
#      None,
#      None],
#     ['0021600001',
#      77,
#      2,
#      47,
#      1,
#      '7:49 PM',
#      '5:16',
#      "MISS Smith 18' Turnaround Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      78,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:14',
#      None,
#      None,
#      'Jennings REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      79,
#      2,
#      42,
#      1,
#      '7:49 PM',
#      '5:05',
#      None,
#      None,
#      'MISS Porzingis  Driving Layup',
#      None,
#      None],
#     ['0021600001',
#      80,
#      4,
#      0,
#      1,
#      '7:49 PM',
#      '5:03',
#      'Thompson REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      81,
#      2,
#      5,
#      1,
#      '7:49 PM',
#      '5:00',
#      "MISS Irving 1' Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      82,
#      4,
#      0,
#      1,
#      '7:50 PM',
#      '5:00',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      83,
#      2,
#      1,
#      1,
#      '7:50 PM',
#      '4:34',
#      None,
#      None,
#      "MISS Jennings 20' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      84,
#      4,
#      0,
#      1,
#      '7:50 PM',
#      '4:34',
#      'James REBOUND (Off:1 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      85,
#      6,
#      1,
#      1,
#      '7:50 PM',
#      '4:34',
#      None,
#      None,
#      "O'Quinn P.FOUL (P1.T3) (B.Adams)",
#      None,
#      None],
#     ['0021600001',
#      87,
#      6,
#      17,
#      1,
#      '7:51 PM',
#      '4:25',
#      None,
#      None,
#      "Knicks T.Foul (Def. 3 Sec O'Quinn ) (B.Kennedy)",
#      None,
#      None],
#     ['0021600001',
#      88,
#      3,
#      16,
#      1,
#      '7:51 PM',
#      '4:25',
#      'Irving Free Throw Technical (3 PTS)',
#      None,
#      None,
#      '12 - 15',
#      '3'],
#     ['0021600001',
#      90,
#      8,
#      0,
#      1,
#      '7:51 PM',
#      '4:25',
#      None,
#      None,
#      'SUB: Thomas FOR Porzingis',
#      None,
#      None],
#     ['0021600001',
#      91,
#      8,
#      0,
#      1,
#      '7:51 PM',
#      '4:25',
#      'SUB: Shumpert FOR Smith',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      93,
#      1,
#      42,
#      1,
#      '7:51 PM',
#      '4:16',
#      "Irving 2' Driving Layup (5 PTS)",
#      None,
#      None,
#      '12 - 17',
#      '5'],
#     ['0021600001',
#      94,
#      1,
#      52,
#      1,
#      '7:52 PM',
#      '4:05',
#      None,
#      None,
#      "Anthony  Alley Oop Dunk (9 PTS) (O'Quinn 1 AST)",
#      '14 - 17',
#      '3'],
#     ['0021600001',
#      95,
#      2,
#      42,
#      1,
#      '7:52 PM',
#      '3:49',
#      "MISS Irving 2' Driving Layup",
#      None,
#      "O'Quinn BLOCK (1 BLK)",
#      None,
#      None],
#     ['0021600001',
#      96,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '3:46',
#      'Shumpert REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      97,
#      2,
#      1,
#      1,
#      '7:52 PM',
#      '3:41',
#      "MISS Jefferson 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      99,
#      4,
#      0,
#      1,
#      '7:52 PM',
#      '3:37',
#      'James REBOUND (Off:2 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      98,
#      1,
#      87,
#      1,
#      '7:52 PM',
#      '3:37',
#      'James  Putback Dunk (6 PTS)',
#      None,
#      None,
#      '14 - 19',
#      '5'],
#     ['0021600001',
#      100,
#      1,
#      1,
#      1,
#      '7:52 PM',
#      '3:17',
#      None,
#      None,
#      "Anthony 16' Jump Shot (11 PTS)",
#      '16 - 19',
#      '3'],
#     ['0021600001',
#      101,
#      2,
#      1,
#      1,
#      '7:53 PM',
#      '3:04',
#      "MISS Shumpert 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      102,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      103,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      'SUB: Dunleavy FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      105,
#      8,
#      0,
#      1,
#      '7:53 PM',
#      '3:04',
#      'SUB: Love FOR Irving',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      106,
#      2,
#      1,
#      1,
#      '7:53 PM',
#      '2:50',
#      None,
#      None,
#      "MISS Thomas 23' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      107,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '2:50',
#      'Jefferson REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      108,
#      2,
#      40,
#      1,
#      '7:53 PM',
#      '2:43',
#      "MISS Love 2' Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      110,
#      4,
#      0,
#      1,
#      '7:53 PM',
#      '2:43',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      112,
#      9,
#      1,
#      1,
#      '7:54 PM',
#      '2:43',
#      None,
#      None,
#      'Knicks Timeout: Regular (Reg.1 Short 0)',
#      None,
#      None],
#     ['0021600001',
#      114,
#      18,
#      1,
#      1,
#      '7:54 PM',
#      '2:43',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      117,
#      2,
#      98,
#      1,
#      '7:56 PM',
#      '2:40',
#      "MISS Love 2' Cutting Layup Shot",
#      None,
#      "O'Quinn BLOCK (2 BLK)",
#      None,
#      None],
#     ['0021600001',
#      118,
#      4,
#      0,
#      1,
#      '7:56 PM',
#      '2:39',
#      None,
#      None,
#      'Lee REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      119,
#      6,
#      4,
#      1,
#      '7:57 PM',
#      '2:37',
#      None,
#      None,
#      "O'Quinn OFF.Foul (P2) (K.Lane)",
#      None,
#      None],
#     ['0021600001',
#      120,
#      5,
#      5,
#      1,
#      '7:57 PM',
#      '2:37',
#      None,
#      None,
#      "O'Quinn Foul Turnover (P1.T5)",
#      None,
#      None],
#     ['0021600001',
#      121,
#      1,
#      80,
#      1,
#      '7:57 PM',
#      '2:16',
#      "Love 14' Step Back Jump Shot (5 PTS) (Shumpert 1 AST)",
#      None,
#      None,
#      '16 - 21',
#      '5'],
#     ['0021600001',
#      122,
#      5,
#      2,
#      1,
#      '7:57 PM',
#      '2:00',
#      'Jefferson STEAL (1 STL)',
#      None,
#      'Anthony Lost Ball Turnover (P2.T6)',
#      None,
#      None],
#     ['0021600001',
#      123,
#      1,
#      50,
#      1,
#      '7:58 PM',
#      '1:55',
#      'Jefferson  Running Dunk (2 PTS)',
#      None,
#      None,
#      '16 - 23',
#      '7'],
#     ['0021600001',
#      124,
#      5,
#      45,
#      1,
#      '7:58 PM',
#      '1:40',
#      None,
#      None,
#      'Anthony Out of Bounds - Bad Pass Turnover Turnover (P3.T7)',
#      None,
#      None],
#     ['0021600001',
#      125,
#      8,
#      0,
#      1,
#      '7:58 PM',
#      '1:40',
#      None,
#      None,
#      'SUB: Holiday FOR Anthony',
#      None,
#      None],
#     ['0021600001',
#      126,
#      6,
#      2,
#      1,
#      '7:58 PM',
#      '1:28',
#      None,
#      None,
#      'Thomas S.FOUL (P1.T4) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      127,
#      3,
#      11,
#      1,
#      '7:59 PM',
#      '1:28',
#      'MISS Love Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      128,
#      4,
#      1,
#      1,
#      '7:59 PM',
#      '1:28',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      129,
#      8,
#      0,
#      1,
#      '7:59 PM',
#      '1:28',
#      None,
#      None,
#      'SUB: Hernangomez FOR Lee',
#      None,
#      None],
#     ['0021600001',
#      130,
#      3,
#      12,
#      1,
#      '7:59 PM',
#      '1:28',
#      'Love Free Throw 2 of 2 (6 PTS)',
#      None,
#      None,
#      '16 - 24',
#      '8'],
#     ['0021600001',
#      133,
#      2,
#      1,
#      1,
#      '7:59 PM',
#      '1:11',
#      None,
#      None,
#      "MISS O'Quinn 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      134,
#      4,
#      0,
#      1,
#      '7:59 PM',
#      '1:10',
#      'Love REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      135,
#      6,
#      4,
#      1,
#      '8:00 PM',
#      '1:06',
#      'Shumpert OFF.Foul (P1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      136,
#      5,
#      5,
#      1,
#      '8:00 PM',
#      '1:06',
#      'Shumpert Foul Turnover (P1.T1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      138,
#      6,
#      2,
#      1,
#      '8:00 PM',
#      '0:50',
#      'Thompson S.FOUL (P1.T2) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      139,
#      3,
#      11,
#      1,
#      '8:00 PM',
#      '0:50',
#      None,
#      None,
#      'Jennings Free Throw 1 of 2 (1 PTS)',
#      '17 - 24',
#      '7'],
#     ['0021600001',
#      141,
#      3,
#      12,
#      1,
#      '8:01 PM',
#      '0:50',
#      None,
#      None,
#      'Jennings Free Throw 2 of 2 (2 PTS)',
#      '18 - 24',
#      '6'],
#     ['0021600001',
#      144,
#      6,
#      1,
#      1,
#      '8:01 PM',
#      '0:40',
#      None,
#      None,
#      'Thomas P.FOUL (P2.PN) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      145,
#      3,
#      11,
#      1,
#      '8:01 PM',
#      '0:40',
#      'MISS Love Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      146,
#      4,
#      1,
#      1,
#      '8:01 PM',
#      '0:40',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      147,
#      8,
#      0,
#      1,
#      '8:02 PM',
#      '0:40',
#      'SUB: Frye FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      148,
#      3,
#      12,
#      1,
#      '8:02 PM',
#      '0:40',
#      'Love Free Throw 2 of 2 (7 PTS)',
#      None,
#      None,
#      '18 - 25',
#      '7'],
#     ['0021600001',
#      151,
#      2,
#      1,
#      1,
#      '8:02 PM',
#      '0:29',
#      None,
#      None,
#      "MISS Jennings 24' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      152,
#      4,
#      0,
#      1,
#      '8:02 PM',
#      '0:29',
#      None,
#      None,
#      'Hernangomez REBOUND (Off:1 Def:0)',
#      None,
#      None],
#     ['0021600001',
#      153,
#      2,
#      1,
#      1,
#      '8:02 PM',
#      '0:09',
#      'Frye BLOCK (1 BLK)',
#      None,
#      "MISS Thomas 15' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      154,
#      4,
#      0,
#      1,
#      '8:02 PM',
#      '0:09',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      155,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      'SUB: Irving FOR Shumpert',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      156,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      'SUB: James FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      157,
#      8,
#      0,
#      1,
#      '8:03 PM',
#      '0:09',
#      None,
#      None,
#      "SUB: Lee FOR O'Quinn",
#      None,
#      None],
#     ['0021600001',
#      159,
#      1,
#      1,
#      1,
#      '8:03 PM',
#      '0:03',
#      "Love 24' 3PT Jump Shot (10 PTS) (James 5 AST)",
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      161,
#      2,
#      1,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      "MISS Jennings 52' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      162,
#      4,
#      0,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      163,
#      13,
#      0,
#      1,
#      '8:03 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      165,
#      12,
#      0,
#      2,
#      '8:07 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      '18 - 28',
#      '10'],
#     ['0021600001',
#      166,
#      2,
#      1,
#      2,
#      '8:07 PM',
#      '11:46',
#      "MISS Frye 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      167,
#      4,
#      0,
#      2,
#      '8:07 PM',
#      '11:45',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      168,
#      2,
#      1,
#      2,
#      '8:07 PM',
#      '11:29',
#      None,
#      None,
#      "MISS Holiday 18' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      169,
#      4,
#      0,
#      2,
#      '8:07 PM',
#      '11:29',
#      'Irving REBOUND (Off:1 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      170,
#      2,
#      74,
#      2,
#      '8:07 PM',
#      '11:26',
#      "MISS Irving 3' Running Reverse Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      171,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '11:24',
#      'James REBOUND (Off:3 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      172,
#      2,
#      1,
#      2,
#      '8:08 PM',
#      '11:20',
#      'MISS Irving  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      173,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '11:19',
#      'Frye REBOUND (Off:1 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      174,
#      1,
#      7,
#      2,
#      '8:08 PM',
#      '10:55',
#      'James  Dunk (8 PTS) (Jefferson 1 AST)',
#      None,
#      None,
#      '18 - 30',
#      '12'],
#     ['0021600001',
#      175,
#      5,
#      1,
#      2,
#      '8:08 PM',
#      '10:47',
#      'Dunleavy STEAL (1 STL)',
#      None,
#      'Hernangomez Bad Pass Turnover (P1.T8)',
#      None,
#      None],
#     ['0021600001',
#      176,
#      2,
#      41,
#      2,
#      '8:08 PM',
#      '10:42',
#      "MISS James 3' Running Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      178,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '10:40',
#      'Frye REBOUND (Off:2 Def:0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      177,
#      2,
#      97,
#      2,
#      '8:08 PM',
#      '10:40',
#      "MISS Frye 1' Tip Layup Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      179,
#      4,
#      0,
#      2,
#      '8:08 PM',
#      '10:40',
#      None,
#      None,
#      'Thomas REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      180,
#      2,
#      1,
#      2,
#      '8:09 PM',
#      '10:23',
#      None,
#      None,
#      "MISS Thomas 22' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      181,
#      4,
#      0,
#      2,
#      '8:09 PM',
#      '10:23',
#      'Dunleavy REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      182,
#      2,
#      1,
#      2,
#      '8:09 PM',
#      '10:11',
#      "MISS Frye 25' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      183,
#      4,
#      0,
#      2,
#      '8:09 PM',
#      '10:11',
#      None,
#      None,
#      'Jennings REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      184,
#      1,
#      5,
#      2,
#      '8:09 PM',
#      '10:02',
#      None,
#      None,
#      "Hernangomez 1' Layup (2 PTS) (Jennings 1 AST)",
#      '20 - 30',
#      '10'],
#     ['0021600001',
#      185,
#      1,
#      7,
#      2,
#      '8:09 PM',
#      '9:46',
#      'Jefferson  Dunk (4 PTS) (James 6 AST)',
#      None,
#      None,
#      '20 - 32',
#      '12'],
#     ['0021600001',
#      189,
#      6,
#      2,
#      2,
#      '8:10 PM',
#      '9:36',
#      'Frye S.FOUL (P1.T1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      190,
#      3,
#      11,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'Jennings Free Throw 1 of 2 (3 PTS)',
#      '21 - 32',
#      '11'],
#     ['0021600001',
#      192,
#      8,
#      0,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'SUB: Porzingis FOR Hernangomez',
#      None,
#      None],
#     ['0021600001',
#      193,
#      3,
#      12,
#      2,
#      '8:10 PM',
#      '9:36',
#      None,
#      None,
#      'Jennings Free Throw 2 of 2 (4 PTS)',
#      '22 - 32',
#      '10'],
#     ['0021600001',
#      195,
#      6,
#      1,
#      2,
#      '8:11 PM',
#      '9:27',
#      None,
#      None,
#      'Porzingis P.FOUL (P2.T1) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      196,
#      8,
#      0,
#      2,
#      '8:11 PM',
#      '9:27',
#      None,
#      None,
#      'SUB: Rose FOR Jennings',
#      None,
#      None],
#     ['0021600001',
#      197,
#      2,
#      1,
#      2,
#      '8:11 PM',
#      '9:12',
#      "MISS Dunleavy 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      198,
#      4,
#      0,
#      2,
#      '8:11 PM',
#      '9:12',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      199,
#      1,
#      79,
#      2,
#      '8:11 PM',
#      '9:01',
#      None,
#      None,
#      "Rose 12' Pullup Jump Shot (4 PTS)",
#      '24 - 32',
#      '8'],
#     ['0021600001',
#      201,
#      2,
#      1,
#      2,
#      '8:11 PM',
#      '8:48',
#      "MISS Irving 15' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      202,
#      4,
#      0,
#      2,
#      '8:11 PM',
#      '8:48',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:0 Def:1)",
#      None,
#      None],
#     ['0021600001',
#      203,
#      5,
#      2,
#      2,
#      '8:12 PM',
#      '8:41',
#      'Jefferson STEAL (2 STL)',
#      None,
#      'Rose Lost Ball Turnover (P3.T9)',
#      None,
#      None],
#     ['0021600001',
#      204,
#      1,
#      50,
#      2,
#      '8:12 PM',
#      '8:36',
#      'James  Running Dunk (10 PTS) (Irving 2 AST)',
#      None,
#      None,
#      '24 - 34',
#      '10'],
#     ['0021600001',
#      205,
#      9,
#      1,
#      2,
#      '8:12 PM',
#      '8:36',
#      None,
#      None,
#      'Knicks Timeout: Regular (Reg.2 Short 0)',
#      None,
#      None],
#     ['0021600001',
#      207,
#      8,
#      0,
#      2,
#      '8:15 PM',
#      '8:36',
#      None,
#      None,
#      "SUB: Anthony FOR O'Quinn",
#      None,
#      None],
#     ['0021600001',
#      209,
#      5,
#      1,
#      2,
#      '8:15 PM',
#      '8:23',
#      'Frye STEAL (1 STL)',
#      None,
#      'Rose Bad Pass Turnover (P4.T10)',
#      None,
#      None],
#     ['0021600001',
#      210,
#      5,
#      40,
#      2,
#      '8:15 PM',
#      '8:12',
#      'Jefferson Out of Bounds Lost Ball Turnover (P1.T2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      211,
#      2,
#      1,
#      2,
#      '8:16 PM',
#      '7:58',
#      None,
#      None,
#      "MISS Porzingis 15' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      212,
#      4,
#      0,
#      2,
#      '8:16 PM',
#      '7:57',
#      'James REBOUND (Off:3 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      236,
#      5,
#      1,
#      2,
#      '8:16 PM',
#      '7:46',
#      'James Bad Pass Turnover (P1.T3)',
#      None,
#      'Porzingis STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      213,
#      6,
#      1,
#      2,
#      '8:16 PM',
#      '7:45',
#      'Irving P.FOUL (P1.T2) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      215,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Shumpert FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      216,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Smith FOR Dunleavy',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      217,
#      8,
#      0,
#      2,
#      '8:16 PM',
#      '7:45',
#      'SUB: Thompson FOR Frye',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      218,
#      8,
#      0,
#      2,
#      '8:17 PM',
#      '7:45',
#      None,
#      None,
#      'SUB: Noah FOR Thomas',
#      None,
#      None],
#     ['0021600001',
#      219,
#      2,
#      1,
#      2,
#      '8:17 PM',
#      '7:36',
#      'Shumpert BLOCK (1 BLK)',
#      None,
#      "MISS Anthony 5' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      220,
#      4,
#      0,
#      2,
#      '8:17 PM',
#      '7:35',
#      'James REBOUND (Off:3 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      221,
#      1,
#      52,
#      2,
#      '8:17 PM',
#      '7:33',
#      'James  Alley Oop Dunk (12 PTS) (Irving 3 AST)',
#      None,
#      None,
#      '24 - 36',
#      '12'],
#     ['0021600001',
#      222,
#      6,
#      1,
#      2,
#      '8:17 PM',
#      '7:18',
#      'James P.FOUL (P2.T3) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      224,
#      1,
#      80,
#      2,
#      '8:18 PM',
#      '7:07',
#      None,
#      None,
#      "Rose 8' Step Back Jump Shot (6 PTS)",
#      '26 - 36',
#      '10'],
#     ['0021600001',
#      225,
#      1,
#      1,
#      2,
#      '8:18 PM',
#      '6:50',
#      "Smith 25' 3PT Jump Shot (8 PTS) (James 7 AST)",
#      None,
#      None,
#      '26 - 39',
#      '13'],
#     ['0021600001',
#      226,
#      1,
#      1,
#      2,
#      '8:18 PM',
#      '6:30',
#      None,
#      None,
#      "Anthony 15' Jump Shot (13 PTS)",
#      '28 - 39',
#      '11'],
#     ['0021600001',
#      227,
#      5,
#      1,
#      2,
#      '8:19 PM',
#      '6:16',
#      'Thompson Bad Pass Turnover (P1.T4)',
#      None,
#      'Noah STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      228,
#      1,
#      41,
#      2,
#      '8:19 PM',
#      '6:11',
#      None,
#      None,
#      'Rose  Running Layup (8 PTS)',
#      '30 - 39',
#      '9'],
#     ['0021600001',
#      229,
#      9,
#      1,
#      2,
#      '8:19 PM',
#      '6:11',
#      'CAVALIERS Timeout: Regular (Full 2 Short 0)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      233,
#      6,
#      4,
#      2,
#      '8:22 PM',
#      '6:02',
#      'Thompson OFF.Foul (P2) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      234,
#      5,
#      5,
#      2,
#      '8:22 PM',
#      '6:02',
#      'Thompson Foul Turnover (P2.T5)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      237,
#      8,
#      0,
#      2,
#      '8:22 PM',
#      '6:02',
#      'SUB: Love FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      238,
#      1,
#      1,
#      2,
#      '8:23 PM',
#      '5:47',
#      None,
#      None,
#      "Porzingis 24' 3PT Jump Shot (6 PTS) (Holiday 1 AST)",
#      '33 - 39',
#      '6'],
#     ['0021600001',
#      239,
#      6,
#      1,
#      2,
#      '8:23 PM',
#      '5:33',
#      None,
#      None,
#      'Anthony P.FOUL (P2.T2) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      241,
#      2,
#      1,
#      2,
#      '8:24 PM',
#      '5:18',
#      "MISS Smith 17' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      242,
#      4,
#      0,
#      2,
#      '8:24 PM',
#      '5:18',
#      None,
#      None,
#      'Porzingis REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      243,
#      1,
#      1,
#      2,
#      '8:24 PM',
#      '5:11',
#      None,
#      None,
#      "Holiday 24' 3PT Jump Shot (3 PTS) (Anthony 1 AST)",
#      '36 - 39',
#      '3'],
#     ['0021600001',
#      244,
#      1,
#      42,
#      2,
#      '8:24 PM',
#      '4:55',
#      "Irving 1' Driving Layup (7 PTS)",
#      None,
#      None,
#      '36 - 41',
#      '5'],
#     ['0021600001',
#      245,
#      1,
#      1,
#      2,
#      '8:24 PM',
#      '4:40',
#      None,
#      None,
#      "Holiday 25' 3PT Jump Shot (6 PTS) (Anthony 2 AST)",
#      '39 - 41',
#      '2'],
#     ['0021600001',
#      246,
#      2,
#      1,
#      2,
#      '8:24 PM',
#      '4:29',
#      "MISS Love 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      247,
#      4,
#      0,
#      2,
#      '8:24 PM',
#      '4:28',
#      'Thompson REBOUND (Off:1 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      248,
#      2,
#      1,
#      2,
#      '8:25 PM',
#      '4:19',
#      "MISS Love 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      249,
#      4,
#      0,
#      2,
#      '8:25 PM',
#      '4:19',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      251,
#      1,
#      5,
#      2,
#      '8:25 PM',
#      '4:13',
#      None,
#      None,
#      "Rose 1' Layup (10 PTS)",
#      '41 - 41',
#      'TIE'],
#     ['0021600001',
#      253,
#      1,
#      1,
#      2,
#      '8:25 PM',
#      '3:59',
#      "Irving 24' 3PT Jump Shot (10 PTS)",
#      None,
#      None,
#      '41 - 44',
#      '3'],
#     ['0021600001',
#      254,
#      6,
#      1,
#      2,
#      '8:25 PM',
#      '3:46',
#      'Shumpert P.FOUL (P2.T4) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      255,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:41',
#      None,
#      None,
#      'MISS Rose  3PT Jump Shot',
#      None,
#      None],
#     ['0021600001',
#      256,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:40',
#      'Love REBOUND (Off:0 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      257,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:30',
#      "MISS Smith 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      258,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:30',
#      'Thompson REBOUND (Off:2 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      259,
#      2,
#      1,
#      2,
#      '8:26 PM',
#      '3:17',
#      "MISS Shumpert 19' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      260,
#      4,
#      0,
#      2,
#      '8:26 PM',
#      '3:17',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      261,
#      6,
#      1,
#      2,
#      '8:26 PM',
#      '3:17',
#      'Thompson P.FOUL (P3.PN) (K.Lane)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      262,
#      3,
#      11,
#      2,
#      '8:26 PM',
#      '3:17',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (7 PTS)',
#      '42 - 44',
#      '2'],
#     ['0021600001',
#      264,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      'SUB: James FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      265,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      'SUB: Jefferson FOR Irving',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      266,
#      8,
#      0,
#      2,
#      '8:27 PM',
#      '3:17',
#      None,
#      None,
#      'SUB: Lee FOR Noah',
#      None,
#      None],
#     ['0021600001',
#      267,
#      3,
#      12,
#      2,
#      '8:27 PM',
#      '3:17',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      269,
#      4,
#      0,
#      2,
#      '8:27 PM',
#      '3:16',
#      'Love REBOUND (Off:0 Def:5)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      271,
#      1,
#      49,
#      2,
#      '8:27 PM',
#      '3:09',
#      'Jefferson  Driving Dunk (6 PTS) (Shumpert 2 AST)',
#      None,
#      None,
#      '42 - 46',
#      '4'],
#     ['0021600001',
#      272,
#      2,
#      79,
#      2,
#      '8:28 PM',
#      '2:52',
#      None,
#      None,
#      "MISS Holiday 16' Pullup Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      273,
#      4,
#      0,
#      2,
#      '8:28 PM',
#      '2:50',
#      'Love REBOUND (Off:0 Def:6)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      274,
#      2,
#      1,
#      2,
#      '8:28 PM',
#      '2:44',
#      'MISS Smith  3PT Jump Shot',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      275,
#      4,
#      0,
#      2,
#      '8:28 PM',
#      '2:43',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      276,
#      6,
#      3,
#      2,
#      '8:28 PM',
#      '2:43',
#      None,
#      None,
#      'Anthony L.B.FOUL (P3.T3) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      277,
#      9,
#      4,
#      2,
#      '8:28 PM',
#      '2:43',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      279,
#      8,
#      0,
#      2,
#      '8:31 PM',
#      '2:43',
#      None,
#      None,
#      'SUB: Thomas FOR Anthony',
#      None,
#      None],
#     ['0021600001',
#      281,
#      5,
#      2,
#      2,
#      '8:31 PM',
#      '2:37',
#      'James Lost Ball Turnover (P2.T6)',
#      None,
#      'Thomas STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      282,
#      5,
#      2,
#      2,
#      '8:31 PM',
#      '2:28',
#      'Smith STEAL (1 STL)',
#      None,
#      'Lee Lost Ball Turnover (P1.T11)',
#      None,
#      None],
#     ['0021600001',
#      283,
#      5,
#      40,
#      2,
#      '8:31 PM',
#      '2:20',
#      'Jefferson Out of Bounds Lost Ball Turnover (P2.T7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      284,
#      2,
#      42,
#      2,
#      '8:32 PM',
#      '2:08',
#      None,
#      None,
#      "MISS Rose 1' Driving Layup",
#      None,
#      None],
#     ['0021600001',
#      285,
#      4,
#      0,
#      2,
#      '8:32 PM',
#      '2:07',
#      'Smith REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      287,
#      5,
#      1,
#      2,
#      '8:32 PM',
#      '1:54',
#      'Love Bad Pass Turnover (P1.T8)',
#      None,
#      'Holiday STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      288,
#      2,
#      1,
#      2,
#      '8:32 PM',
#      '1:47',
#      None,
#      None,
#      "MISS Lee 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      289,
#      4,
#      0,
#      2,
#      '8:32 PM',
#      '1:45',
#      None,
#      None,
#      'Rose REBOUND (Off:2 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      290,
#      1,
#      42,
#      2,
#      '8:32 PM',
#      '1:42',
#      None,
#      None,
#      'Rose  Driving Layup (12 PTS)',
#      '44 - 46',
#      '2'],
#     ['0021600001',
#      291,
#      2,
#      1,
#      2,
#      '8:33 PM',
#      '1:15',
#      "MISS James 24' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      292,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '1:15',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      293,
#      5,
#      11,
#      2,
#      '8:33 PM',
#      '1:15',
#      'CAVALIERS Turnover: Shot Clock (T#9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      294,
#      2,
#      1,
#      2,
#      '8:33 PM',
#      '1:05',
#      None,
#      None,
#      "MISS Porzingis 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      295,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '1:05',
#      'Love REBOUND (Off:0 Def:7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      296,
#      2,
#      78,
#      2,
#      '8:33 PM',
#      '0:52',
#      "MISS James 10' Floating Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      297,
#      4,
#      0,
#      2,
#      '8:33 PM',
#      '0:51',
#      None,
#      None,
#      'Holiday REBOUND (Off:0 Def:3)',
#      None,
#      None],
#     ['0021600001',
#      298,
#      6,
#      2,
#      2,
#      '8:33 PM',
#      '0:38',
#      'Love S.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      299,
#      3,
#      11,
#      2,
#      '8:34 PM',
#      '0:38',
#      None,
#      None,
#      'Porzingis Free Throw 1 of 2 (8 PTS)',
#      '45 - 46',
#      '1'],
#     ['0021600001',
#      301,
#      3,
#      12,
#      2,
#      '8:34 PM',
#      '0:38',
#      None,
#      None,
#      'MISS Porzingis Free Throw 2 of 2',
#      None,
#      None],
#     ['0021600001',
#      303,
#      4,
#      0,
#      2,
#      '8:34 PM',
#      '0:36',
#      'Love REBOUND (Off:0 Def:8)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      304,
#      1,
#      79,
#      2,
#      '8:34 PM',
#      '0:27',
#      "Shumpert 14' Pullup Jump Shot (2 PTS)",
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      305,
#      9,
#      2,
#      2,
#      '8:35 PM',
#      '0:16',
#      None,
#      None,
#      'Knicks Timeout: Short (Reg.2 Short 1)',
#      None,
#      None],
#     ['0021600001',
#      307,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      None,
#      None,
#      'SUB: Anthony FOR Thomas',
#      None,
#      None],
#     ['0021600001',
#      308,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      'SUB: McRae FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      309,
#      8,
#      0,
#      2,
#      '8:36 PM',
#      '0:16',
#      'SUB: Dunleavy FOR Shumpert',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      310,
#      2,
#      1,
#      2,
#      '8:36 PM',
#      '0:02',
#      None,
#      None,
#      "MISS Anthony 26' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      311,
#      4,
#      0,
#      2,
#      '8:36 PM',
#      '0:01',
#      None,
#      None,
#      'Porzingis REBOUND (Off:2 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      312,
#      2,
#      63,
#      2,
#      '8:36 PM',
#      '0:01',
#      None,
#      None,
#      "MISS Porzingis 10' Fadeaway Jumper",
#      None,
#      None],
#     ['0021600001',
#      313,
#      4,
#      0,
#      2,
#      '8:36 PM',
#      '0:00',
#      'Love REBOUND (Off:0 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      314,
#      13,
#      0,
#      2,
#      '8:36 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      316,
#      12,
#      0,
#      3,
#      '8:54 PM',
#      '12:00',
#      None,
#      None,
#      None,
#      '45 - 48',
#      '3'],
#     ['0021600001',
#      317,
#      2,
#      1,
#      3,
#      '8:54 PM',
#      '11:46',
#      "MISS Smith 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      318,
#      4,
#      0,
#      3,
#      '8:54 PM',
#      '11:46',
#      'Love REBOUND (Off:1 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      319,
#      6,
#      26,
#      3,
#      '8:55 PM',
#      '11:42',
#      'Love Offensive Charge Foul (P2.T1) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      320,
#      5,
#      5,
#      3,
#      '8:55 PM',
#      '11:42',
#      'Love Foul Turnover (P2.T10)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      321,
#      2,
#      1,
#      3,
#      '8:55 PM',
#      '11:29',
#      None,
#      None,
#      "MISS Anthony 12' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      322,
#      4,
#      0,
#      3,
#      '8:55 PM',
#      '11:29',
#      'Thompson REBOUND (Off:2 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      323,
#      2,
#      1,
#      3,
#      '8:55 PM',
#      '11:07',
#      "MISS Irving 14' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      325,
#      4,
#      0,
#      3,
#      '8:55 PM',
#      '11:04',
#      'Love REBOUND (Off:2 Def:9)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      324,
#      1,
#      97,
#      3,
#      '8:55 PM',
#      '11:04',
#      "Love 2' Tip Layup Shot (12 PTS)",
#      None,
#      None,
#      '45 - 50',
#      '5'],
#     ['0021600001',
#      326,
#      5,
#      1,
#      3,
#      '8:56 PM',
#      '10:51',
#      'Love STEAL (2 STL)',
#      None,
#      'Lee Bad Pass Turnover (P2.T12)',
#      None,
#      None],
#     ['0021600001',
#      327,
#      6,
#      29,
#      3,
#      '8:56 PM',
#      '10:47',
#      None,
#      None,
#      'Lee Shooting Block Foul (P1.T1) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      328,
#      3,
#      11,
#      3,
#      '8:56 PM',
#      '10:47',
#      'MISS James Free Throw 1 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      329,
#      4,
#      1,
#      3,
#      '8:56 PM',
#      '10:47',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      330,
#      3,
#      12,
#      3,
#      '8:57 PM',
#      '10:47',
#      'James Free Throw 2 of 2 (13 PTS)',
#      None,
#      None,
#      '45 - 51',
#      '6'],
#     ['0021600001',
#      333,
#      2,
#      80,
#      3,
#      '8:57 PM',
#      '10:34',
#      None,
#      None,
#      "MISS Rose 17' Step Back Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      334,
#      4,
#      0,
#      3,
#      '8:57 PM',
#      '10:32',
#      None,
#      None,
#      'Lee REBOUND (Off:1 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      335,
#      5,
#      39,
#      3,
#      '8:57 PM',
#      '10:29',
#      None,
#      None,
#      'Anthony Step Out of Bounds Turnover (P4.T13)',
#      None,
#      None],
#     ['0021600001',
#      336,
#      2,
#      1,
#      3,
#      '8:57 PM',
#      '10:17',
#      "MISS Love 26' 3PT Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      337,
#      4,
#      0,
#      3,
#      '8:58 PM',
#      '10:17',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      338,
#      2,
#      66,
#      3,
#      '8:58 PM',
#      '9:58',
#      None,
#      None,
#      "MISS Porzingis 13' Jump Bank Shot",
#      None,
#      None],
#     ['0021600001',
#      340,
#      4,
#      0,
#      3,
#      '8:58 PM',
#      '9:54',
#      None,
#      None,
#      'Porzingis REBOUND (Off:3 Def:2)',
#      None,
#      None],
#     ['0021600001',
#      339,
#      1,
#      97,
#      3,
#      '8:58 PM',
#      '9:54',
#      None,
#      None,
#      'Porzingis  Tip Layup Shot (10 PTS)',
#      '47 - 51',
#      '4'],
#     ['0021600001',
#      341,
#      1,
#      1,
#      3,
#      '8:58 PM',
#      '9:35',
#      "Irving 28' 3PT Jump Shot (13 PTS) (Smith 1 AST)",
#      None,
#      None,
#      '47 - 54',
#      '7'],
#     ['0021600001',
#      342,
#      1,
#      1,
#      3,
#      '8:59 PM',
#      '9:22',
#      None,
#      None,
#      "Anthony 19' Jump Shot (15 PTS) (Noah 2 AST)",
#      '49 - 54',
#      '5'],
#     ['0021600001',
#      343,
#      1,
#      49,
#      3,
#      '8:59 PM',
#      '9:05',
# ...
#      None,
#      None],
#     ['0021600001',
#      481,
#      1,
#      1,
#      4,
#      '9:34 PM',
#      '8:34',
#      'Jefferson  3PT Jump Shot (9 PTS) (James 14 AST)',
#      None,
#      None,
#      '71 - 92',
#      '21'],
#     ['0021600001',
#      482,
#      1,
#      1,
#      4,
#      '9:35 PM',
#      '8:19',
#      None,
#      None,
#      "Rose 24' 3PT Jump Shot (17 PTS)",
#      '74 - 92',
#      '18'],
#     ['0021600001',
#      483,
#      2,
#      44,
#      4,
#      '9:35 PM',
#      '7:57',
#      "MISS Jefferson 1' Reverse Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      484,
#      4,
#      0,
#      4,
#      '9:35 PM',
#      '7:55',
#      None,
#      None,
#      'Holiday REBOUND (Off:1 Def:5)',
#      None,
#      None],
#     ['0021600001',
#      485,
#      2,
#      1,
#      4,
#      '9:35 PM',
#      '7:50',
#      None,
#      None,
#      "MISS Jennings 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      486,
#      4,
#      0,
#      4,
#      '9:35 PM',
#      '7:48',
#      'Liggins REBOUND (Off:0 Def:1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      487,
#      6,
#      2,
#      4,
#      '9:35 PM',
#      '7:48',
#      None,
#      None,
#      'Porzingis S.FOUL (P4.T3) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      488,
#      3,
#      11,
#      4,
#      '9:36 PM',
#      '7:48',
#      'Jefferson Free Throw 1 of 2 (10 PTS)',
#      None,
#      None,
#      '74 - 93',
#      '19'],
#     ['0021600001',
#      490,
#      8,
#      0,
#      4,
#      '9:36 PM',
#      '7:48',
#      'SUB: Love FOR Frye',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      491,
#      3,
#      12,
#      4,
#      '9:36 PM',
#      '7:48',
#      'MISS Jefferson Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      493,
#      4,
#      0,
#      4,
#      '9:36 PM',
#      '7:47',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      494,
#      6,
#      1,
#      4,
#      '9:36 PM',
#      '7:47',
#      None,
#      None,
#      'Anthony P.FOUL (P4.T4) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      495,
#      8,
#      0,
#      4,
#      '9:37 PM',
#      '7:47',
#      'SUB: Thompson FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      496,
#      6,
#      1,
#      4,
#      '9:37 PM',
#      '7:47',
#      None,
#      None,
#      'Anthony P.FOUL (P5.PN) (K.Lane)',
#      None,
#      None],
#     ['0021600001',
#      497,
#      3,
#      11,
#      4,
#      '9:37 PM',
#      '7:47',
#      'Love Free Throw 1 of 2 (16 PTS)',
#      None,
#      None,
#      '74 - 94',
#      '20'],
#     ['0021600001',
#      499,
#      3,
#      12,
#      4,
#      '9:37 PM',
#      '7:47',
#      'MISS Love Free Throw 2 of 2',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      501,
#      4,
#      0,
#      4,
#      '9:37 PM',
#      '7:46',
#      None,
#      None,
#      'Anthony REBOUND (Off:1 Def:4)',
#      None,
#      None],
#     ['0021600001',
#      502,
#      2,
#      1,
#      4,
#      '9:38 PM',
#      '7:33',
#      None,
#      None,
#      "MISS Anthony 27' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      503,
#      4,
#      0,
#      4,
#      '9:38 PM',
#      '7:33',
#      'James REBOUND (Off:3 Def:6)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      505,
#      6,
#      27,
#      4,
#      '9:38 PM',
#      '7:29',
#      None,
#      None,
#      'Porzingis Personal Block Foul (P5.PN) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      506,
#      3,
#      11,
#      4,
#      '9:38 PM',
#      '7:29',
#      'Love Free Throw 1 of 2 (17 PTS)',
#      None,
#      None,
#      '74 - 95',
#      '21'],
#     ['0021600001',
#      508,
#      3,
#      12,
#      4,
#      '9:38 PM',
#      '7:29',
#      'Love Free Throw 2 of 2 (18 PTS)',
#      None,
#      None,
#      '74 - 96',
#      '22'],
#     ['0021600001',
#      510,
#      2,
#      47,
#      4,
#      '9:39 PM',
#      '7:10',
#      None,
#      None,
#      "MISS Porzingis 13' Turnaround Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      511,
#      4,
#      0,
#      4,
#      '9:39 PM',
#      '7:08',
#      'James REBOUND (Off:3 Def:7)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      513,
#      5,
#      1,
#      4,
#      '9:39 PM',
#      '6:53',
#      'James Bad Pass Turnover (P4.T14)',
#      None,
#      'Anthony STEAL (1 STL)',
#      None,
#      None],
#     ['0021600001',
#      514,
#      2,
#      1,
#      4,
#      '9:39 PM',
#      '6:47',
#      None,
#      None,
#      "MISS Anthony 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      515,
#      4,
#      0,
#      4,
#      '9:39 PM',
#      '6:45',
#      'James REBOUND (Off:3 Def:8)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      516,
#      6,
#      1,
#      4,
#      '9:39 PM',
#      '6:44',
#      None,
#      None,
#      'Jennings P.FOUL (P2.PN) (B.Adams)',
#      None,
#      None],
#     ['0021600001',
#      517,
#      3,
#      11,
#      4,
#      '9:40 PM',
#      '6:44',
#      'Love Free Throw 1 of 2 (19 PTS)',
#      None,
#      None,
#      '74 - 97',
#      '23'],
#     ['0021600001',
#      520,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      'SUB: Jefferson FOR James',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      521,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      None,
#      None,
#      'SUB: Baker FOR Rose',
#      None,
#      None],
#     ['0021600001',
#      522,
#      8,
#      0,
#      4,
#      '9:40 PM',
#      '6:44',
#      None,
#      None,
#      "SUB: O'Quinn FOR Anthony",
#      None,
#      None],
#     ['0021600001',
#      523,
#      3,
#      12,
#      4,
#      '9:40 PM',
#      '6:44',
#      'Love Free Throw 2 of 2 (20 PTS)',
#      None,
#      None,
#      '74 - 98',
#      '24'],
#     ['0021600001',
#      525,
#      1,
#      80,
#      4,
#      '9:41 PM',
#      '6:22',
#      None,
#      None,
#      "Jennings 7' Step Back Jump Shot (7 PTS)",
#      '76 - 98',
#      '22'],
#     ['0021600001',
#      526,
#      1,
#      1,
#      4,
#      '9:41 PM',
#      '5:56',
#      "Jefferson 26' 3PT Jump Shot (13 PTS)",
#      None,
#      None,
#      '76 - 101',
#      '25'],
#     ['0021600001',
#      527,
#      2,
#      1,
#      4,
#      '9:41 PM',
#      '5:48',
#      None,
#      None,
#      "MISS Porzingis 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      528,
#      4,
#      0,
#      4,
#      '9:41 PM',
#      '5:48',
#      'Dunleavy REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      529,
#      1,
#      5,
#      4,
#      '9:41 PM',
#      '5:34',
#      "Love 1' Layup (22 PTS) (Liggins 1 AST)",
#      None,
#      None,
#      '76 - 103',
#      '27'],
#     ['0021600001',
#      530,
#      6,
#      2,
#      4,
#      '9:41 PM',
#      '5:34',
#      None,
#      None,
#      "O'Quinn S.FOUL (P3.PN) (B.Kennedy)",
#      None,
#      None],
#     ['0021600001',
#      531,
#      9,
#      4,
#      4,
#      '9:42 PM',
#      '5:34',
#      None,
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      535,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      None,
#      None,
#      'SUB: Hernangomez FOR Porzingis',
#      None,
#      None],
#     ['0021600001',
#      536,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      None,
#      None,
#      'SUB: Kuzminskas FOR Holiday',
#      None,
#      None],
#     ['0021600001',
#      537,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      'SUB: Andersen FOR Thompson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      538,
#      8,
#      0,
#      4,
#      '9:44 PM',
#      '5:34',
#      'SUB: McRae FOR Jefferson',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      539,
#      3,
#      10,
#      4,
#      '9:45 PM',
#      '5:34',
#      'Love Free Throw 1 of 1 (23 PTS)',
#      None,
#      None,
#      '76 - 104',
#      '28'],
#     ['0021600001',
#      542,
#      6,
#      1,
#      4,
#      '9:45 PM',
#      '5:32',
#      'Liggins P.FOUL (P1.T3) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      543,
#      8,
#      0,
#      4,
#      '9:45 PM',
#      '5:30',
#      'SUB: Jones FOR Love',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      544,
#      2,
#      79,
#      4,
#      '9:45 PM',
#      '5:22',
#      None,
#      None,
#      "MISS Jennings 17' Pullup Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      545,
#      4,
#      0,
#      4,
#      '9:45 PM',
#      '5:21',
#      'Dunleavy REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      546,
#      1,
#      1,
#      4,
#      '9:45 PM',
#      '5:07',
#      "Jones 25' 3PT Jump Shot (3 PTS) (Dunleavy 2 AST)",
#      None,
#      None,
#      '76 - 107',
#      '31'],
#     ['0021600001',
#      548,
#      1,
#      82,
#      4,
#      '9:46 PM',
#      '4:48',
#      None,
#      None,
#      "Baker 10' Driving Bank Shot (2 PTS) (Jennings 3 AST)",
#      '78 - 107',
#      '29'],
#     ['0021600001',
#      549,
#      1,
#      79,
#      4,
#      '9:46 PM',
#      '4:30',
#      "McRae 9' Pullup Jump Shot (2 PTS) (Liggins 2 AST)",
#      None,
#      None,
#      '78 - 109',
#      '31'],
#     ['0021600001',
#      550,
#      1,
#      78,
#      4,
#      '9:46 PM',
#      '4:20',
#      None,
#      None,
#      "Kuzminskas 12' Floating Jump Shot (7 PTS) (Jennings 4 AST)",
#      '80 - 109',
#      '29'],
#     ['0021600001',
#      551,
#      2,
#      42,
#      4,
#      '9:47 PM',
#      '3:59',
#      "MISS McRae 1' Driving Layup",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      552,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:57',
#      None,
#      None,
#      'Baker REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      553,
#      2,
#      1,
#      4,
#      '9:47 PM',
#      '3:49',
#      'Andersen BLOCK (1 BLK)',
#      None,
#      "MISS Baker 4' Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      554,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:48',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:1)",
#      None,
#      None],
#     ['0021600001',
#      555,
#      1,
#      72,
#      4,
#      '9:47 PM',
#      '3:47',
#      None,
#      None,
#      "O'Quinn 1' Putback Layup (2 PTS)",
#      '82 - 109',
#      '27'],
#     ['0021600001',
#      556,
#      2,
#      1,
#      4,
#      '9:47 PM',
#      '3:33',
#      "MISS Liggins 10' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      557,
#      4,
#      0,
#      4,
#      '9:47 PM',
#      '3:32',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:2)",
#      None,
#      None],
#     ['0021600001',
#      558,
#      1,
#      5,
#      4,
#      '9:47 PM',
#      '3:26',
#      None,
#      None,
#      "Hernangomez 3' Layup (4 PTS) (Jennings 5 AST)",
#      '84 - 109',
#      '25'],
#     ['0021600001',
#      560,
#      2,
#      1,
#      4,
#      '9:48 PM',
#      '2:58',
#      "MISS Jones 22' Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      561,
#      4,
#      0,
#      4,
#      '9:48 PM',
#      '2:57',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:3)",
#      None,
#      None],
#     ['0021600001',
#      562,
#      5,
#      1,
#      4,
#      '9:48 PM',
#      '2:55',
#      'Dunleavy STEAL (2 STL)',
#      None,
#      'Jennings Bad Pass Turnover (P1.T17)',
#      None,
#      None],
#     ['0021600001',
#      563,
#      1,
#      42,
#      4,
#      '9:48 PM',
#      '2:44',
#      "Liggins 1' Driving Layup (4 PTS)",
#      None,
#      None,
#      '84 - 111',
#      '27'],
#     ['0021600001',
#      564,
#      2,
#      1,
#      4,
#      '9:48 PM',
#      '2:30',
#      None,
#      None,
#      "MISS O'Quinn 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      565,
#      4,
#      0,
#      4,
#      '9:48 PM',
#      '2:29',
#      'Liggins REBOUND (Off:0 Def:2)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      566,
#      5,
#      45,
#      4,
#      '9:48 PM',
#      '2:27',
#      'Liggins Out of Bounds - Bad Pass Turnover Turnover (P1.T15)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      567,
#      9,
#      1,
#      4,
#      '9:48 PM',
#      '2:27',
#      'CAVALIERS Timeout: Regular (Full 4 Short 1)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      569,
#      8,
#      0,
#      4,
#      '9:51 PM',
#      '2:27',
#      None,
#      None,
#      'SUB: Vujacic FOR Jennings',
#      None,
#      None],
#     ['0021600001',
#      571,
#      6,
#      1,
#      4,
#      '9:51 PM',
#      '2:20',
#      'McRae P.FOUL (P1.T4) (B.Adams)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      572,
#      2,
#      1,
#      4,
#      '9:52 PM',
#      '2:06',
#      None,
#      None,
#      "MISS Kuzminskas 26' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      573,
#      4,
#      0,
#      4,
#      '9:52 PM',
#      '2:06',
#      'CAVALIERS Rebound',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      574,
#      6,
#      3,
#      4,
#      '9:52 PM',
#      '2:06',
#      None,
#      None,
#      'Hernangomez L.B.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None],
#     ['0021600001',
#      575,
#      3,
#      11,
#      4,
#      '9:52 PM',
#      '2:06',
#      'Jones Free Throw 1 of 2 (4 PTS)',
#      None,
#      None,
#      '84 - 112',
#      '28'],
#     ['0021600001',
#      577,
#      3,
#      12,
#      4,
#      '9:52 PM',
#      '2:06',
#      'Jones Free Throw 2 of 2 (5 PTS)',
#      None,
#      None,
#      '84 - 113',
#      '29'],
#     ['0021600001',
#      579,
#      2,
#      98,
#      4,
#      '9:53 PM',
#      '1:50',
#      None,
#      None,
#      "MISS Hernangomez 2' Cutting Layup Shot",
#      None,
#      None],
#     ['0021600001',
#      580,
#      4,
#      0,
#      4,
#      '9:53 PM',
#      '1:50',
#      'Liggins REBOUND (Off:0 Def:3)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      581,
#      2,
#      101,
#      4,
#      '9:53 PM',
#      '1:33',
#      "MISS McRae 7' Driving Floating Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      582,
#      4,
#      0,
#      4,
#      '9:53 PM',
#      '1:33',
#      None,
#      None,
#      "O'Quinn REBOUND (Off:1 Def:4)",
#      None,
#      None],
#     ['0021600001',
#      585,
#      5,
#      1,
#      4,
#      '9:54 PM',
#      '1:18',
#      'Dunleavy STEAL (3 STL)',
#      None,
#      'Vujacic Bad Pass Turnover (P1.T18)',
#      None,
#      None],
#     ['0021600001',
#      586,
#      1,
#      75,
#      4,
#      '9:54 PM',
#      '1:08',
#      'Dunleavy  Driving Finger Roll Layup (4 PTS) (Liggins 3 AST)',
#      None,
#      None,
#      '84 - 115',
#      '31'],
#     ['0021600001',
#      587,
#      6,
#      1,
#      4,
#      '9:54 PM',
#      '1:08',
#      'Jones P.FOUL (P1.PN) (B.Kennedy)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      588,
#      3,
#      11,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'MISS Vujacic Free Throw 1 of 2',
#      None,
#      None],
#     ['0021600001',
#      589,
#      4,
#      1,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'Knicks Rebound',
#      None,
#      None],
#     ['0021600001',
#      590,
#      3,
#      12,
#      4,
#      '9:54 PM',
#      '1:08',
#      None,
#      None,
#      'Vujacic Free Throw 2 of 2 (1 PTS)',
#      '85 - 115',
#      '30'],
#     ['0021600001',
#      593,
#      2,
#      79,
#      4,
#      '9:55 PM',
#      '0:47',
#      "MISS McRae 16' Pullup Jump Shot",
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      594,
#      4,
#      0,
#      4,
#      '9:55 PM',
#      '0:47',
#      None,
#      None,
#      'Kuzminskas REBOUND (Off:0 Def:1)',
#      None,
#      None],
#     ['0021600001',
#      595,
#      2,
#      1,
#      4,
#      '9:55 PM',
#      '0:36',
#      None,
#      None,
#      "MISS Vujacic 25' 3PT Jump Shot",
#      None,
#      None],
#     ['0021600001',
#      596,
#      4,
#      0,
#      4,
#      '9:55 PM',
#      '0:35',
#      'Dunleavy REBOUND (Off:0 Def:4)',
#      None,
#      None,
#      None,
#      None],
#     ['0021600001',
#      597,
#      1,
#      79,
#      4,
#      '9:55 PM',
#      '0:19',
#      "Andersen 17' Pullup Jump Shot (2 PTS)",
#      None,
#      None,
#      '85 - 117',
#      '32'],
#     ['0021600001',
#      598,
#      1,
#      1,
#      4,
#      '9:56 PM',
#      '0:12',
#      None,
#      None,
#      "Baker 28' 3PT Jump Shot (5 PTS) (Vujacic 1 AST)",
#      '88 - 117',
#      '29'],
#     ['0021600001',
#      600,
#      13,
#      0,
#      4,
#      '9:56 PM',
#      '0:00',
#      None,
#      None,
#      None,
#      '88 - 117',
#      '29']]},
#   {'headers': ['VIDEO_AVAILABLE_FLAG'],
#    'name': 'AvailableVideo',
#    'rowSet': [[1]]}]}
