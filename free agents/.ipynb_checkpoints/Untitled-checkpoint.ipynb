# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.feature_selection import RFE

# %matplotlib inline

# %%
fa = pd.read_csv('allFA.csv')
per = pd.read_csv('allPer 36.csv')
adv = pd.read_csv('allAdvanced.csv')

# %%
per = per[per.Rk != 'Rk']
adv = adv[adv.Rk != 'Rk']

fa.rename(columns={fa.columns.values[0]:'Player'}, inplace=True)
fa.rename(columns={'2018 CAP HIT':'Cap Hit'}, inplace=True)

df = fa.merge(per, on=['Player', 'Season']).merge(adv, on=['Player', 'Season'])
cols = [c for c in df.columns if c.lower()[-2:] != '_y']
df=df[cols]
cols = []
for c in df.columns:
    if c.lower()[-2:] == '_x':
        cols.append(c[:-2])
    else:
        cols.append(c)

df.columns = cols
df.replace('0-', 0, inplace=True)
df.replace('-', 0, inplace=True)
# df = df[df.To != 'TBD']
df.iloc[:,7:10] = df[df.columns[7:10]].replace('[\$,]', '', regex=True).astype(float)
df = df.apply(pd.to_numeric, errors='ignore')
df.drop(columns=['OWS','DWS','WS','WS/48','PER','PercCap','TYPE'], inplace=True)
df.rename(columns={'AVG. SALARY':'AvgSalary'}, inplace=True)
df['AvgSalary'] = df.AvgSalary/1000000
df["Cap Hit/Cap"] = df['Cap Hit']/df['Cap']

# %%
traindf = df[df.TO != 'TBD']
cor = traindf.corr()['AvgSalary'].sort_values(ascending=False).to_frame()
cor.drop(labels=['DOLLARS','YRS','Cap Hit/Cap','Cap Hit', 'AvgSalary'], inplace=True)
cmap=sns.diverging_palette(5, 250, as_cmap=True)
cor.style.background_gradient(cmap, axis=0)
# Out:
# <style  type="text/css" >
#     #T_e960c3ba_82f5_11e8_91de_989e632e5a00row0_col0 {
#             background-color:  #4479bb;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row1_col0 {
#             background-color:  #6f98ca;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row2_col0 {
#             background-color:  #739acc;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row3_col0 {
#             background-color:  #749bcc;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row4_col0 {
#             background-color:  #86a8d3;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row5_col0 {
#             background-color:  #8cacd5;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row6_col0 {
#             background-color:  #a6bfde;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row7_col0 {
#             background-color:  #acc3e1;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row8_col0 {
#             background-color:  #adc4e1;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row9_col0 {
#             background-color:  #b5cae4;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row10_col0 {
#             background-color:  #b8cce5;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row11_col0 {
#             background-color:  #bccfe7;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row12_col0 {
#             background-color:  #c7d7eb;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row13_col0 {
#             background-color:  #d7e2f0;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row14_col0 {
#             background-color:  #d9e4f1;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row15_col0 {
#             background-color:  #e3ebf5;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row16_col0 {
#             background-color:  #e6edf6;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row17_col0 {
#             background-color:  #e6edf6;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row18_col0 {
#             background-color:  #ebf1f8;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row19_col0 {
#             background-color:  #f2f2f2;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row20_col0 {
#             background-color:  #f2f2f2;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row21_col0 {
#             background-color:  #fbeaed;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row22_col0 {
#             background-color:  #fae8ec;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row23_col0 {
#             background-color:  #f8dfe4;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row24_col0 {
#             background-color:  #f7dae0;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row25_col0 {
#             background-color:  #f6d1d8;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row26_col0 {
#             background-color:  #f5cfd7;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row27_col0 {
#             background-color:  #f5cfd7;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row28_col0 {
#             background-color:  #f5cfd7;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row29_col0 {
#             background-color:  #f5ccd4;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row30_col0 {
#             background-color:  #f5ccd4;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row31_col0 {
#             background-color:  #f4c8d0;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row32_col0 {
#             background-color:  #f3c6cf;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row33_col0 {
#             background-color:  #f3c5ce;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row34_col0 {
#             background-color:  #f2c1cb;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row35_col0 {
#             background-color:  #f0b4c0;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row36_col0 {
#             background-color:  #efb2bf;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row37_col0 {
#             background-color:  #efb1be;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row38_col0 {
#             background-color:  #efafbc;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row39_col0 {
#             background-color:  #e994a5;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row40_col0 {
#             background-color:  #e993a4;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row41_col0 {
#             background-color:  #e88ea0;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row42_col0 {
#             background-color:  #e4798e;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row43_col0 {
#             background-color:  #e3788d;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row44_col0 {
#             background-color:  #e16b82;
#         }    #T_e960c3ba_82f5_11e8_91de_989e632e5a00row45_col0 {
#             background-color:  #d73c5b;
#         }</style>
# <table id="T_e960c3ba_82f5_11e8_91de_989e632e5a00" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AvgSalary</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row0" class="row_heading level0 row0" >VORP</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row0_col0" class="data row0 col0" >0.829123</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row1" class="row_heading level0 row1" >MP</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row1_col0" class="data row1 col0" >0.68789</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row2" class="row_heading level0 row2" >OBPM</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row2_col0" class="data row2 col0" >0.674943</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row3" class="row_heading level0 row3" >GS</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row3_col0" class="data row3 col0" >0.668639</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row4" class="row_heading level0 row4" >BPM</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row4_col0" class="data row4 col0" >0.609837</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row5" class="row_heading level0 row5" >PTS</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row5_col0" class="data row5 col0" >0.593329</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row6" class="row_heading level0 row6" >FG</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row6_col0" class="data row6 col0" >0.507115</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row7" class="row_heading level0 row7" >FT</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row7_col0" class="data row7 col0" >0.491713</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row8" class="row_heading level0 row8" >USG%</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row8_col0" class="data row8 col0" >0.484732</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row9" class="row_heading level0 row9" >AST%</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row9_col0" class="data row9 col0" >0.456591</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row10" class="row_heading level0 row10" >FTA</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row10_col0" class="data row10 col0" >0.447637</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row11" class="row_heading level0 row11" >FGA</th>
#         <td id="T_e960c3ba_82f5_11e8_91de_989e632e5a00row11_col0" class="data row11 col0" >0.433891</td>
#     </tr>    <tr>
#         <th id="T_e960c3ba_82f5_11e8_91de_989e632e5a00level0_row12" class="row_heading level0 row12" >AST</th>
#         <td id="T_e

# %%
from sklearn.linear_model import LinearRegression
features = ['VORP','GS', 'PF']
X = traindf[features]
y = traindf['AvgSalary']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

regr = LinearRegression()

regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

resid = (y_test - y_pred)
rss = np.sum(resid**2)
se = np.sqrt(rss/(len(resid) - (len(features)-1)))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
salMean = y.mean()
mae = mean_absolute_error(y_test,y_pred)
mape = mae/salMean
percError = se/salMean
print (features)
print('Coefficients: \n', regr.coef_)
print("RSS: %.2f" % rss)
print("MSE: %.2f" % mean_squared_error(y_test, y_pred))
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("Mean Salary: %.2f" % salMean)
print("SE: %.2f" % se)
print("MAPE: %.3f " % mape )
print("Percent Error: %.3f " % percError )
# Explained variance score: 1 is perfect prediction
print('Variance score: %f' % regr.score(X_train,y_train))
# Out:
# ['VORP', 'GS', 'PF']
# Coefficients:
#  [ 3.82648915  0.07797552 -1.23912406]
# RSS: 765.48
# MSE: 16.29
# RMSE: 4.04
# MAE: 3.10
# Mean Salary: 8.21
# SE: 4.12
# MAPE: 0.378
# Percent Error: 0.502
# Variance score: 0.743736

# %%
from sklearn.linear_model import RidgeCV
traindf.dropna(axis=1, inplace=True)
myfeats = ['Age','G', 'GS', 'MP', 'FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT',
       'FTA', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF',
       'PTS', 'FG%', '2P%', 'eFG%', 'TS%', 'FTr',
       'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
       'ORtg', 'DRtg', 'OBPM', 'DBPM', 'BPM', 'VORP']
X = traindf[myfeats]
y = traindf['AvgSalary']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

clf = RidgeCV()
clf.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = clf.predict(X_test)

resid = (y_test - y_pred)
rss = np.sum(resid**2)
se = np.sqrt(rss/(len(resid) - (len(features)-1)))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
salMean = y.mean()
mae = mean_absolute_error(y_test,y_pred)
mape = mae/salMean
percError = se/salMean


print("RSS: %.2f" % rss)
print("MSE: %.2f" % mean_squared_error(y_test, y_pred))
print("RMSE: %.2f" % rmse)
print("MAE: %.2f" % mae)
print("Mean Salary: %.2f" % salMean)
print("SE: %.2f" % se)
print("MAPE: %.3f " % mape )
print("Percent Error: %.3f " % percError )
# Explained variance score: 1 is perfect prediction
print('Variance score: %f' % clf.score(X_train,y_train))
# Out:
# RSS: 810.27
# MSE: 17.24
# RMSE: 4.15
# MAE: 3.11
# Mean Salary: 8.21
# SE: 4.24
# MAPE: 0.379
# Percent Error: 0.517
# Variance score: 0.816617
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
bldf = df[df.Player == 'LeBron James']
blX = bldf[myfeats]
print(blX)
brookLopezPred = clf.predict(blX)
print(brookLopezPred)
# Out:
#      Age   G  GS    MP    FG   FGA   2P   2PA   3P  3PA  ...   STL%  BLK%  \
# 100   33  82  82  3026  10.2  18.8  8.4  14.0  1.8  4.8  ...    1.9   2.0
#
#      TOV%  USG%  ORtg  DRtg  OBPM  DBPM  BPM  VORP
# 100  16.1  31.6   118   109   7.6   2.0  9.6   8.9
#
# [1 rows x 40 columns]
# [40.43222122]

# %%
pred2 = clf.predict(X)
resid2 = (y-pred2)

ilist = resid2.index.tolist()

# %%
from matplotlib.lines import Line2D
customLegend = [Line2D([0], [0], marker='o', color='w', label='2016-17 FA',
                          markerfacecolor='gray', alpha=0.3, markersize=8)]
curFA = traindf[traindf.Season == '2017-18']
sns.set_style("whitegrid")
sns.set_palette('deep', curFA.shape[0] )
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111)

ax.axhline(linestyle='dashed')
i = 0
for pt in range(0,resid2.shape[0]):
    curdf = traindf.iloc[pt,:]
    if curdf['Season'] == '2017-18':
        p = ax.plot(pred2[pt], resid2.iloc[pt],'o')
        if (np.abs(resid2.iloc[pt]) > 2) | (y.iloc[pt] > 5):
            ax.annotate(traindf.Player.iloc[pt], xy=(pred2[pt], resid2.iloc[pt]),color=p[0].get_color(), fontsize='x-large', fontweight="bold")
        i = i+1
    else:
        ax.plot(pred2[pt], resid2.iloc[pt],'o', color='gray', alpha=0.3, label='2016-17 FA')
ax.legend(handles = customLegend)
